# %% [markdown]
# # GraphRAG: Knowledge Graph-Enhanced Catalog Search
#
# This notebook builds on the standard RAG approach by constructing a **knowledge graph** from the
# hardware catalogs. Instead of relying solely on vector similarity, GraphRAG:
#
# 1. **Extracts entities and relationships** from document chunks using an LLM
# 2. **Builds a knowledge graph** with products, specifications, and their connections
# 3. **Detects communities** of related entities for hierarchical summarization
# 4. **Retrieves via graph traversal + vector search** for richer context
# 5. **Compares** GraphRAG vs standard RAG on different query types
#
# ## When GraphRAG Shines
#
# | Query Type | Standard RAG | GraphRAG |
# |-----------|-------------|----------|
# | Specific fact lookup | Great | Good |
# | Multi-hop reasoning | Weak | Strong |
# | Global/thematic questions | Weak | Strong |
# | Cross-document synthesis | Weak | Strong |
#
# ## Prerequisites
#
# ```bash
# pip install -r requirements.txt
# ollama pull nomic-embed-text
# ollama pull mistral:7b
# ```

# %%
# %pip install -q pymupdf chromadb anthropic openai python-dotenv httpx networkx pyvis
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## 1. Setup & Configuration

# %%
# ── Model configuration ───────────────────────────────────────────────
# Each task has its own provider ("anthropic" or "ollama") and model.

EXTRACTION_PROVIDER = "anthropic"
EXTRACTION_MODEL    = "claude-sonnet-4-20250514"

SUMMARY_PROVIDER    = "anthropic"
SUMMARY_MODEL       = "claude-sonnet-4-20250514"

ANSWER_PROVIDER     = "anthropic"
ANSWER_MODEL        = "claude-sonnet-4-20250514"

EMBED_MODEL         = "nomic-embed-text"  # Always runs via Ollama

# ── Pipeline settings ─────────────────────────────────────────────────

MAX_PAGES_PER_PDF   = None      # None = all pages
FORCE_RE_EXTRACT    = False     # True = ignore cached extractions
CHUNK_SIZE          = 800
CHUNK_OVERLAP       = 100

# ── Paths & connection ────────────────────────────────────────────────

CATALOG_DIR         = "../../catalogs"
CHROMA_PERSIST_DIR  = "../chroma_db_graph"
GRAPH_PERSIST_PATH  = "../knowledge_graph.json"
OLLAMA_BASE_URL     = "http://localhost:11434"

# %%
import os
import json
import re
import time
from pathlib import Path
from difflib import SequenceMatcher
from dotenv import load_dotenv

load_dotenv(Path("../.env"))

# Convert path strings to Path objects
CATALOG_DIR = Path(CATALOG_DIR)
CHROMA_PERSIST_DIR = Path(CHROMA_PERSIST_DIR)
GRAPH_PERSIST_PATH = Path(GRAPH_PERSIST_PATH)

print(f"Anthropic API key: {'loaded' if os.getenv('ANTHROPIC_API_KEY') else 'MISSING'}")
print(f"\nExtraction:          {EXTRACTION_PROVIDER} / {EXTRACTION_MODEL}")
print(f"Community summaries: {SUMMARY_PROVIDER} / {SUMMARY_MODEL}")
print(f"Answer generation:   {ANSWER_PROVIDER} / {ANSWER_MODEL}")
print(f"Embeddings:          ollama / {EMBED_MODEL}")
print(f"\nPages per PDF: {MAX_PAGES_PER_PDF or 'All'}  |  Force re-extract: {FORCE_RE_EXTRACT}")
# Out:
# Anthropic API key: loaded
#
# Extraction:          anthropic / claude-sonnet-4-20250514
# Community summaries: anthropic / claude-sonnet-4-20250514
# Answer generation:   anthropic / claude-sonnet-4-20250514
# Embeddings:          ollama / nomic-embed-text
#
# Pages per PDF: All  |  Force re-extract: False

# %% [markdown]
# ## 2. Extract and Chunk PDFs
#
# Same extraction as the standard RAG notebook, but with smaller chunks optimized for entity extraction.

# %%
import fitz  # PyMuPDF


def extract_pdf_pages(pdf_path: Path, max_pages: int | None = None) -> list[dict]:
    """Extract text from each page of a PDF."""
    documents = []
    doc = fitz.open(pdf_path)
    num_pages = min(len(doc), max_pages) if max_pages else len(doc)
    for page_num in range(num_pages):
        page = doc[page_num]
        text = page.get_text().strip()
        if text and len(text) > 50:  # Skip near-blank pages
            documents.append({
                "text": text,
                "metadata": {
                    "source": pdf_path.name,
                    "page": page_num + 1,
                },
            })
    doc.close()
    return documents


def chunk_text(text: str, chunk_size: int = CHUNK_SIZE, overlap: int = CHUNK_OVERLAP) -> list[str]:
    """Split text into overlapping chunks."""
    if len(text) <= chunk_size:
        return [text]
    chunks = []
    start = 0
    while start < len(text):
        end = start + chunk_size
        if end < len(text):
            search_start = start + int(chunk_size * 0.8)
            last_break = max(text.rfind(".", search_start, end), text.rfind("\n", search_start, end))
            if last_break > search_start:
                end = last_break + 1
        chunk = text[start:end].strip()
        if chunk:
            chunks.append(chunk)
        start = end - overlap
    return chunks


# Extract and chunk
all_chunks = []
for pdf_path in sorted(CATALOG_DIR.glob("*.pdf")):
    pages = extract_pdf_pages(pdf_path, max_pages=MAX_PAGES_PER_PDF)
    for page_doc in pages:
        for i, chunk in enumerate(chunk_text(page_doc["text"])):
            all_chunks.append({
                "id": f"chunk_{len(all_chunks)}",
                "text": chunk,
                "metadata": {**page_doc["metadata"], "chunk_index": i},
            })
    print(f"  {pdf_path.name}: {len(pages)} pages")

print(f"\nTotal chunks: {len(all_chunks)}")
# Out:
#   grass-nexis-catalog.pdf: 51 pages
#   grass-tiomos-catalog.pdf: 63 pages
#   wurth-baer-section-b-concealed-hinges.pdf: 104 pages
#   Wurth_Baer_Section_C.pdf: 56 pages
#
# Total chunks: 676

# %% [markdown]
# ## 3. Entity & Relationship Extraction with LLM
#
# This is the core of GraphRAG. We send each chunk to an LLM and ask it to extract:
# - **Entities**: products, manufacturers, specifications, materials, features
# - **Relationships**: triples of (subject, predicate, object)
#
# We use Ollama locally so this step is free (but takes time).

# %%
import anthropic
from openai import OpenAI

# Anthropic client
anthropic_client = anthropic.Anthropic()

# Ollama client
ollama_client = OpenAI(
    base_url=f"{OLLAMA_BASE_URL}/v1",
    api_key="ollama",
)


def llm_chat(prompt: str, provider: str, model: str, temperature: float = 0.0, max_tokens: int = 1024) -> str:
    """Send a prompt to the specified provider/model and return the response text."""
    if provider == "anthropic":
        response = anthropic_client.messages.create(
            model=model,
            max_tokens=max_tokens,
            temperature=temperature,
            messages=[{"role": "user", "content": prompt}],
        )
        return response.content[0].text.strip()
    elif provider == "ollama":
        response = ollama_client.chat.completions.create(
            model=model,
            messages=[{"role": "user", "content": prompt}],
            temperature=temperature,
        )
        return response.choices[0].message.content.strip()
    else:
        raise ValueError(f"Unknown provider: {provider}. Use 'anthropic' or 'ollama'.")


EXTRACTION_PROMPT = """Extract entities and relationships from this hardware catalog text.

ENTITY TYPES (use ONLY these exact values):
  product, manufacturer, feature, specification, material, certification, category

RELATIONSHIP TYPES (use ONLY these exact values):
  has_feature, manufactured_by, has_specification, compatible_with, part_of, variant_of

Return ONLY a valid JSON object with no markdown formatting, no code blocks, no extra text.
Use "relation" as the key for relationship type (not "type").

Example:
{"entities": [{"name": "Tiomos", "type": "product"}], "relationships": [{"source": "Tiomos", "relation": "manufactured_by", "target": "Grass"}]}

TEXT:
$TEXT$

JSON:"""


def extract_entities_and_relations(chunk_text: str, retries: int = 2) -> dict:
    """Extract entities and relationships using EXTRACTION_PROVIDER / EXTRACTION_MODEL."""
    for attempt in range(retries + 1):
        try:
            content = llm_chat(
                EXTRACTION_PROMPT.replace("$TEXT$", chunk_text),
                provider=EXTRACTION_PROVIDER,
                model=EXTRACTION_MODEL,
                temperature=0.0,
                max_tokens=1024,
            )

            # Strip markdown code blocks if present
            content = re.sub(r"^```json\s*", "", content)
            content = re.sub(r"\s*```$", "", content)

            json_match = re.search(r"\{[\s\S]*\}", content)
            if json_match:
                parsed = json.loads(json_match.group())
                entities = parsed.get("entities", [])
                relationships = parsed.get("relationships", [])
                for rel in relationships:
                    if "type" in rel and "relation" not in rel:
                        rel["relation"] = rel.pop("type")
                return {"entities": entities, "relationships": relationships}
            else:
                if attempt == retries:
                    print(f"No JSON in response: {content[:200]}")
        except anthropic.BadRequestError as e:
            error_msg = str(e)
            if "credit balance" in error_msg.lower():
                raise RuntimeError("Anthropic API credits exhausted. Top up at console.anthropic.com/settings/billing") from e
            if attempt == retries:
                print(f"API error: {e}")
        except anthropic.AuthenticationError as e:
            raise RuntimeError(f"Invalid API key. Check ANTHROPIC_API_KEY in .env: {e}") from e
        except anthropic.APIConnectionError as e:
            if attempt == retries:
                print(f"Connection error (check internet): {e}")
        except json.JSONDecodeError as e:
            if attempt == retries:
                print(f"JSON parse error: {e}")
        except Exception as e:
            if attempt == retries:
                print(f"Unexpected error: {type(e).__name__}: {e}")
    return {"entities": [], "relationships": []}


# Quick test
test_result = extract_entities_and_relations(all_chunks[5]["text"])
if test_result["entities"]:
    print(f"Extraction OK ({EXTRACTION_PROVIDER} / {EXTRACTION_MODEL})")
    print(json.dumps(test_result, indent=2))
else:
    print("Warning: test extraction returned no entities. Check API credits and connection.")
# Out:
# Extraction OK (anthropic / claude-sonnet-4-20250514)
# {
#   "entities": [
#     {
#       "name": "Nexis Impresso hinge cup",
#       "type": "product"
#     },
#     {
#       "name": "42mm/45mm pattern",
#       "type": "specification"
#     },
#     {
#       "name": "45mm/48mm pattern",
#       "type": "specification"
#     },
#     {
#       "name": "3 point fixing",
#       "type": "feature"
#     },
#     {
#       "name": "screw-on",
#       "type": "feature"
#     },
#     {
#       "name": "Euro screw",
#       "type": "feature"
#     },
#     {
#       "name": "face frame cabinetry",
#       "type": "category"
#     },
#     {
#       "name": "frameless cabinetry",
#       "type": "category"
#     },
#     {
#       "name": "snap-on method",
#       "type": "feature"
#     },
#     {
#       "name": "Soft-close",
#       "type": "feature"
#     }
#   ],
#   "relationships": [
#     {
#       "source": "Nexis Impresso hinge cup",
#       "relation": "has_specification",
#       "target": "42mm/45mm pattern"
#     },
#     {
#       "source": "Nexis Impresso hinge cup",
#       "relation": "has_specification",
#       "target": "45mm/48mm pattern"
#     },
#     {
#       "source": "Nexis Impresso hinge cup",
#       "relation": "has_feature",
#       "target": "3 point fixing"
#     },
#     {
#       "source": "Nexis Impresso hinge cup",
#       "relation": "has_feature",
#       "target": "screw-on"
#     },
#     {
#       "source": "Nexis Impresso hinge cup",
#       "relation": "has_feature",
#       "target": "Euro screw"
#     },
#     {
#       "source": "Nexis Impresso hinge cup",
#       "relation": "compatible_with",
#       "target": "face frame cabinetry"
#     },
#     {
#       "source": "Nexis Impresso hinge cup",
#       "relation": "compatible_with",
#       "target": "frameless cabinetry"
#     },
#     {
#       "source": "Nexis Impresso hinge cup",
#       "relation": "has_feature",
#       "target": "snap-on method"
#     },
#     {
#       "source": "Nexis Impresso hinge cup",
#       "relation": "has_feature",
#       "target": "Soft-close"
#     }
#   ]
# }

# %% [markdown]
# ## 4. Run Extraction on All Chunks
#
# This is the most time-consuming step. Each chunk is sent through the LLM for entity/relationship extraction. Progress is printed and results are saved to disk so you don't have to re-run.

# %%
# Check if we already have saved extraction results
extractions_path = Path("../extractions.json")

if extractions_path.exists() and not FORCE_RE_EXTRACT:
    print("Loading saved extractions from disk...")
    with open(extractions_path) as f:
        all_extractions = json.load(f)
    print(f"Loaded {len(all_extractions)} extractions")
else:
    print(f"Extracting entities from {len(all_chunks)} chunks...")
    all_extractions = []
    start_time = time.time()
    errors = 0

    for i, chunk in enumerate(all_chunks):
        result = extract_entities_and_relations(chunk["text"])
        result["chunk_id"] = chunk["id"]
        result["source"] = chunk["metadata"]["source"]
        result["page"] = chunk["metadata"]["page"]
        all_extractions.append(result)

        # Abort early if too many consecutive failures
        if not result["entities"] and not result["relationships"]:
            errors += 1
            if errors >= 10 and i < 20:
                print(f"Too many extraction failures ({errors}/{i+1}). Check API credits/connection.")
                break
        else:
            errors = 0

        total_e = sum(len(e.get("entities", [])) for e in all_extractions)
        total_r = sum(len(e.get("relationships", [])) for e in all_extractions)
        elapsed = time.time() - start_time
        rate = (i + 1) / elapsed if elapsed > 0 else 0
        remaining = (len(all_chunks) - i - 1) / rate if rate > 0 else 0
        print(f"  [{i+1}/{len(all_chunks)}] Entities: {total_e}, Relations: {total_r} (~{remaining:.0f}s remaining)")

        if (i + 1) % 50 == 0:
            with open(extractions_path, "w") as f:
                json.dump(all_extractions, f)

    # Only save if we actually got results
    total_e = sum(len(e.get("entities", [])) for e in all_extractions)
    if total_e > 0:
        with open(extractions_path, "w") as f:
            json.dump(all_extractions, f)
        print(f"Saved {len(all_extractions)} extractions")
    else:
        print("No entities extracted - not saving (check API credits)")

print()
print(f"Chunks: {len(all_extractions)}")
total_e = sum(len(e.get("entities", [])) for e in all_extractions)
total_r = sum(len(e.get("relationships", [])) for e in all_extractions)
print(f"Raw entities: {total_e}, Raw relationships: {total_r}")
# Out:
# Loading saved extractions from disk...
# Loaded 658 extractions
#
# Chunks: 658
# Raw entities: 7583, Raw relationships: 5750

# %% [markdown]
# ## 4a. Post-Process Extractions
#
# Normalize entity types and relationship types to a small fixed set, deduplicate entities via fuzzy matching, and filter noise. This dramatically improves graph quality.

# %%
# === Normalize entity types ===
ENTITY_TYPE_MAP = {
    "product": "product", "product_model": "product", "product_variant": "product",
    "product_code": "product", "product_id": "product", "product_series": "product",
    "product_line": "product", "product_component": "product", "component": "product",
    "accessory": "product", "accessory_item": "product", "part": "product",
    "variant": "product", "hinge_style": "product", "tool": "product",
    "item_number": "product",
    "manufacturer": "manufacturer", "company": "manufacturer", "brand": "manufacturer",
    "supplier": "manufacturer",
    "feature": "feature", "product_feature": "feature", "function": "feature",
    "technology": "feature", "action": "feature", "property": "feature",
    "attribute": "feature", "description": "feature",
    "specification": "specification", "product_specification": "specification",
    "dimension": "specification", "weight": "specification", "size": "specification",
    "value": "specification", "quantity": "specification", "unit_of_measurement": "specification",
    "unit_of_measure": "specification", "pattern": "specification",
    "drill_pattern": "specification", "drilling_pattern": "specification",
    "fixing_method": "specification", "number": "specification",
    "material": "material",
    "certification": "certification", "standard": "certification",
    "category": "category", "section": "category", "application": "category",
    "product_application": "category", "usage": "category", "cabinetry": "category",
    "context": "category", "location": "category", "document": "category",
}

# === Normalize relationship types ===
RELATION_TYPE_MAP = {
    "has_feature": "has_feature", "includes_feature": "has_feature",
    "includes": "has_feature", "has_close_type": "has_feature",
    "includes_technology": "has_feature", "has_opening": "has_feature",
    "has_position": "has_feature", "provides": "has_feature",
    "enables": "has_feature", "controls": "has_feature",
    "integrated_with": "has_feature", "has_power_factor_range": "has_feature",
    "offers": "has_feature",
    "has_specification": "has_specification", "has_dimension": "has_specification",
    "has_weight": "has_specification", "has_pattern": "has_specification",
    "has_fixing": "has_specification", "has_unit_of_measure": "has_specification",
    "has_description": "has_specification", "has_cabinet_height_range": "has_specification",
    "is_unit_of": "has_specification", "has": "has_specification",
    "has_number": "has_specification",
    "part_of": "part_of", "is_part_of": "part_of", "contains": "part_of",
    "consists_of": "part_of", "belongs_to": "part_of",
    "compatible_with": "compatible_with", "suitable_for": "compatible_with",
    "suited_for": "compatible_with", "applies_to": "compatible_with",
    "applicable_to": "compatible_with", "used_for": "compatible_with",
    "recommended_for": "compatible_with", "recommends": "compatible_with",
    "attaches_to": "compatible_with", "found_on": "compatible_with",
    "for": "compatible_with",
    "manufactured_by": "manufactured_by",
    "variant_of": "variant_of", "is_variant_of": "variant_of",
    "made_of": "has_specification",
}

# Apply normalization
unmapped_types = set()
unmapped_rels = set()

for extraction in all_extractions:
    for entity in extraction.get("entities", []):
        raw_type = str(entity.get("type", "unknown")).lower().strip()
        mapped = ENTITY_TYPE_MAP.get(raw_type)
        if mapped:
            entity["type"] = mapped
        else:
            if raw_type is not None: unmapped_types.add(raw_type)
            entity["type"] = "feature"

    for rel in extraction.get("relationships", []):
        raw_rel = rel.get("relation", "related_to")
        if raw_rel:
            raw_rel = str(raw_rel).lower().strip()
        mapped = RELATION_TYPE_MAP.get(raw_rel)
        if mapped:
            rel["relation"] = mapped
        else:
            if raw_rel is not None: unmapped_rels.add(raw_rel)
            rel["relation"] = "has_feature"

    # Filter out relationships with None/empty/non-string source or target
    extraction["relationships"] = [
        r for r in extraction.get("relationships", [])
        if r.get("source") and r.get("target")
        and isinstance(r.get("source"), str) and isinstance(r.get("target"), str)
    ]

print("Entity type normalization complete")
if unmapped_types:
    print(f"  Unmapped types (defaulted to 'feature'): {sorted(unmapped_types)}")

print("\nRelationship type normalization complete")
if unmapped_rels:
    print(f"  Unmapped relations (defaulted to 'has_feature'): {sorted(unmapped_rels)}")

# Show new distributions
from collections import Counter
type_counts = Counter()
rel_counts = Counter()
for ex in all_extractions:
    for e in ex.get("entities", []):
        type_counts[e["type"]] += 1
    for r in ex.get("relationships", []):
        rel_counts[r["relation"]] += 1

print(f"\nEntity types ({len(type_counts)}): {dict(type_counts.most_common())}")
print(f"Relationship types ({len(rel_counts)}): {dict(rel_counts.most_common())}")
# Out:
# Entity type normalization complete
#
# Relationship type normalization complete
#   Unmapped relations (defaulted to 'has_feature'): ['has_material']
#
# Entity types (7): {'product': 2679, 'specification': 2120, 'feature': 1715, 'category': 412, 'material': 408, 'manufacturer': 215, 'certification': 34}
# Relationship types (6): {'has_specification': 2042, 'has_feature': 1889, 'part_of': 799, 'compatible_with': 385, 'variant_of': 343, 'manufactured_by': 292}

# %%
# === Entity deduplication via fuzzy matching ===

def build_merge_map(extractions):
    name_counts = {}
    for ex in extractions:
        for e in ex.get("entities", []):
            name = str(e.get("name", "")).strip().title()
            if name:
                name_counts[name] = name_counts.get(name, 0) + 1
        for r in ex.get("relationships", []):
            for key in ["source", "target"]:
                val = r.get(key)
                if val and isinstance(val, str):
                    name = val.strip().title()
                    name_counts[name] = name_counts.get(name, 0) + 1

    names = sorted(name_counts.keys())
    merge_map = {}

    for i, name_a in enumerate(names):
        if name_a in merge_map:
            continue
        for name_b in names[i+1:]:
            if name_b in merge_map:
                continue

            a_norm = name_a.lower().replace("-", " ").replace("_", " ").strip()
            b_norm = name_b.lower().replace("-", " ").replace("_", " ").strip()

            if a_norm == b_norm:
                canonical = name_a if name_counts[name_a] >= name_counts[name_b] else name_b
                variant = name_b if canonical == name_a else name_a
                merge_map[variant] = canonical
                continue

            if len(a_norm) < 30 and len(b_norm) < 30 and len(a_norm) > 3 and len(b_norm) > 3:
                ratio = SequenceMatcher(None, a_norm, b_norm).ratio()
                if ratio >= 0.92:
                    canonical = name_a if name_counts[name_a] >= name_counts[name_b] else name_b
                    variant = name_b if canonical == name_a else name_a
                    merge_map[variant] = canonical

    return merge_map


merge_map = build_merge_map(all_extractions)
print(f"Merging {len(merge_map)} entity variants:")
for v, c in sorted(merge_map.items()):
    print(f"  '{v}' -> '{c}'")

for ex in all_extractions:
    for e in ex.get("entities", []):
        name = str(e.get("name", "")).strip().title()
        e["name"] = merge_map.get(name, name)
    for r in ex.get("relationships", []):
        for key in ["source", "target"]:
            val = r.get(key)
            if val and isinstance(val, str):
                name = val.strip().title()
                r[key] = merge_map.get(name, name)

print(f"\nDeduplication applied to all extractions")
# Out:
# Merging 403 entity variants:
#   '#18 Euro Hinge Insertion Ram' -> 'Euro Hinge Insertion Ram'
#   '#4 X 5/8" Fhp' -> '#6 X 5/8" Fhp'
#   '#40 Euro Hinge Insertion Ram' -> '#18 Euro Hinge Insertion Ram'
#   '#6 Flathead Screws' -> '#5 Flathead Screws'
#   '#6 X 1" Fhp Wood Screw' -> '#6 X 1/2" Fhp Wood Screw'
#   '#6 X 1/2" Screws' -> '#5 X 1/2" Screws'
#   '#6 X 5/8" Wood Screws' -> '#6 X 5/8 Wood Screw'
#   '+/-2Mm' -> '+3/-2Mm'
#   '+45° Angle' -> '-45° Angle'
#   '-15° Angle Corner Cabinets' -> '45° Angle Corner Cabinets'
#   '-45° Angle Corner Cabinets' -> '-15° Angle Corner Cabinets'
#   '-5° Wedge For Screw Fixing' -> '+5° Wedge For Screw Fixing'
#   '1/2 Inch Inset Recess' -> '1 Inch Inset Recess'
#   '1/4 Inch Inset Recess' -> '1 Inch Inset Recess'
#   '104° Restriction Clip' -> '100° Restriction Clip'
#   '105° Opening Angle' -> '120° Opening Angle'
#   '106 Degree Opening' -> '165 Degree Opening'
#   '107° Opening Angle' -> '105° Opening Angle'
#   '108° Opening Angle' -> '110° Opening Angle'
#   '10Mm Cup Depth' -> '10.8Mm Cup Depth'
#   '110 Degree Opening' -> '106 Degree Opening'
#   '110 Degree Opening Angle' -> '105 Degree Opening Angle'
#   '110V Single Phase Pneumatic' -> '220V Single Phase Pneumatic'
#   '110° Clip Top Hinges' -> '107° Clip Top Hinges'
#   '113° Opening Angle' -> '110° Opening Angle'
#   '1200 Angle Reduction Clip' -> '120° Angle Reduction Clip'
#   '120° Opening Angle' -> '108° Opening Angle'
#   '1230 Series Template Inserts' -> '1131 Series Template Inserts'
#   '125° Opening Angle' -> '105° Opening Angle'
#   '125° Wide Angle Hinges' -> '155° Wide Angle Hinge'
#   '12Mm Cup Depth' -> '11Mm Cup Depth'
#   '12Mm Diameter' -> '10Mm Diameter'
#   '12Mm To 28Mm Door Thickness' -> '12Mm-28Mm Door Thickness'
#   '13.5Mm Hinge Cup Boring Depth' -> '12Mm Hinge Cup Boring Depth'
#   '135° Opening Angle' -> '105° Opening Angle'
#   '13Mm Cup Depth' -> '11Mm Cup Depth'
#   '13Mm Height' -> '3Mm Height'
#   '140º Opening Angle' -> '170º Opening Angle'
#   '14Mm Door Thickness' -> '24Mm Door Thickness'
#   '14Mm To 24Mm Door Thickness' -> '12Mm To 28Mm Door Thickness'
#   '15.5Mm Hinge Cup Boring Depth' -> '12Mm Hinge Cup Boring Depth'
#   '150° Opening Angle' -> '105° Opening Angle'
#   '155° Opening Angle' -> '105° Opening Angle'
#   '155° Wide Angle Hinges' -> '125° Wide Angle Hinges'
#   '15Mm Door Thickness' -> '14Mm Door Thickness'
#   '16 To 22Mm Door Thickness' -> '15 To 21Mm Door Thickness'
#   '1600Mm' -> '1600 Mm'
#   '16Mm Door Thickness' -> '14Mm Door Thickness'
#   '16Mm Height' -> '6Mm Height'
#   '17/32" Door Overlay' -> '15/32" Door Overlay'
#   '170° Hinges' -> '170° Hinge'
#   '170° Opening Angle' -> '105° Opening Angle'
#   '170° Wide Angle Hinges' -> '170° Wide-Angle Hinges'
#   '170° Wide-Angle Hinge' -> '170° Wide Angle Hinges'
#   '17Mm Cup Depth' -> '11Mm Cup Depth'
#   '180° To 270° Opening Angles' -> '180° - 270° Opening Angles'
#   '18Mm Euro Screw' -> '13Mm Euro Screw'
#   '19Mm Door Thickness' -> '14Mm Door Thickness'
#   '2 Dimensional Adjustment' -> '3-Dimensional Adjustments'
#   '2-Point Fixing' -> '2 Point Fixing'
#   '2.5Mm Stop Collar' -> '5Mm Stop Collar'
#   '200Mm-480Mm Flap Height' -> '200Mm – 480Mm Flap Height'
#   '21Mm Base Plate' -> '19Mm Base Plate'
#   '2200Mm' -> '2200 Mm'
#   '24Mm Overlay Accommodation' -> '19Mm Overlay Accommodation'
#   '25/32" Hinge Overlay' -> '23/32" Hinge Overlay'
#   '25Mm Height' -> '2.5Mm Height'
#   '3 Cam Adjustments' -> '2 Cam Adjustments'
#   '3 Dimensional Adjustment' -> '3-Dimensional Adjustment'
#   '3 Point Fixing' -> '2 Point Fixing'
#   '3-Dimensional Adjustments' -> '3 Dimensional Adjustment'
#   '3/8 Inch Inset Recess' -> '3/4 Inch Inset Recess'
#   '30,000 Cycles' -> '50,000 Cycles'
#   '30° Opening Angle' -> '90° Opening Angle'
#   '32Mm Door Thickness' -> '24Mm Door Thickness'
#   '35Mm Full Cup Drill Hole' -> '35 Mm Full Cup Drill Hole'
#   '36Mm Door Thickness' -> '30Mm Door Thickness'
#   '375 Series Overlay Hinge' -> '374 Series Overlay Hinge'
#   '376 Series Overlay Hinge' -> '374 Series Overlay Hinge'
#   '4 Fixing Points' -> '3 Fixing Points'
#   '4 Point Fixing' -> '2 Point Fixing'
#   '4-Point Fixing' -> '2 Point Fixing'
#   '40Mm Door Thickness' -> '14Mm Door Thickness'
#   '42/45Mm Boring Pattern' -> '45Mm Boring Pattern'
#   '42Mm Boring Pattern' -> '45Mm Boring Pattern'
#   '42Mm/45Mm Pattern' -> '42/45Mm Pattern'
#   '45/48Mm Boring Pattern' -> '45Mm Boring Pattern'
#   '45Mm Drilling Pattern' -> '42Mm Drilling Pattern'
#   '45° Angle Corner Cabinets' -> '30° Angle Corner Cabinets'
#   '48(1 7/8")' -> '48 (1 7/8")'
#   '48Mm Boring Pattern' -> '42Mm Boring Pattern'
#   '4Mm Drilling Distance' -> '3Mm Drilling Distance'
#   '5Mm Allen Wrench' -> '3Mm Allen Wrench'
#   '5Mm Diameter' -> '2.5Mm Diameter'
#   '5Mm Right Twist Bit' -> '10Mm Right Twist Bit'
#   '600 Mm' -> '1600 Mm'
#   '65° Hinge Application' -> '25° Hinge Application'
#   '6Mm Material Thickness' -> '10Mm Material Thickness'
#   '6Mm Right Twist Bit' -> '10Mm Right Twist Bit'
#   '7/8 Inch Door Thickness' -> '5/8 Inch Door Thickness'
#   '7/8 Inch Inset Recess' -> '5/8 Inch Inset Recess'
#   '72" Cut Length' -> '12" Cut Length'
#   '8 Spindle Head' -> '9-Spindle Head'
#   '8.6Mm X 12Mm Square Dowe' -> '8.6Mm X 12Mm Square Dowel'
#   '80 Degree Position' -> '70 Degree Position'
#   '850 Angle Reduction Clip' -> '85° Angle Reduction Clip'
#   '85° Opening Angle' -> '95° Opening Angle'
#   '8Mm Bits' -> '8Mm Bit'
#   '8Mm Door Thickness' -> '6Mm Door Thickness'
#   '8Mm Material Thickness' -> '10Mm Material Thickness'
#   '8Mm Right Twist Bit' -> '10Mm Right Twist Bit'
#   '8Mm X 11Mm Round Dowel' -> '8Mm X 10Mm Round Dowel'
#   '9 Spindle Head' -> '8 Spindle Head'
#   '9-Spindle Head' -> '8-Spindle Head'
#   '9/16"D/1-7/8"L Slot' -> '7/16"D/1-7/8"L Slot'
#   '90 Degree Opening Angle' -> '105 Degree Opening Angle'
#   '90,000 Cycles' -> '30,000 Cycles'
#   '90° Opening Angle' -> '95° Opening Angle'
#   '975 Vz Pie Cut Corner Hinge' -> '975 Pie-Cut Corner Hinge'
#   '975 Vz Pie Cut Corner Hinge Kit' -> '975 Vz Pie-Cut Corner Hinge Kit'
#   '975 Vz Pie-Cut Corner Hinge' -> '975 Pie-Cut Corner Hinge'
#   '9Mm Height' -> '19Mm Height'
#   'Airsoft Bumper Pad' -> 'Airsoft Bumper Pads'
#   'Ambpr7565-G10' -> 'Ambpr7550-G10'
#   'Ambpr7565-Orb' -> 'Ambpr7550-Orb'
#   'Ampk3180Tm-Fb' -> 'Ampk3180Tb-Fb'
#   'Ampk3180Tm-G10' -> 'Ampk3180Tb-G10'
#   'Ampk3180Tm-G9' -> 'Ampk3180Tb-G9'
#   'Ampk3180Tm-Orb' -> 'Ampk3180Tb-Orb'
#   'Angle Reduction Clip, 120°' -> 'Angle Reduction Clip To 120°'
#   'Angle Reduction Clip, 85°' -> 'Angle Reduction Clip To 85°'
#   'Angle Reduction Clips' -> 'Angle Reduction Clip'
#   'Ansi/Bhma A156.9 - Grade Ii' -> 'Ansi/Bhma A156.9 - Grade I'
#   'Arm Assembly Mounting Plate' -> 'Arm Assembly Mounting Plates'
#   'Aventos Hk Cover Set' -> 'Aventos Hf Cover Set'
#   'Aventos Hk Servo-Drive Set' -> 'Aventos Hf Servo-Drive Set'
#   'Aventos Hk-S Tip-On' -> 'Aventos Hk Tip-On'
#   'Aventos Hk-Xs' -> 'Aventos Hk-S'
#   'Aventos Hl Cover Set' -> 'Aventos Hf Cover Set'
#   'Aventos Hl Servo-Drive Set' -> 'Aventos Hf Servo-Drive Set'
#   'Aventos Hs Arm Assembly Set' -> 'Aventos Hl Arm Assembly Set'
#   'Aventos Hs Cover Set' -> 'Aventos Hf Cover Set'
#   'Aventos Hs Rod Connector Set' -> 'Aventos Hl Rod Connector Set'
#   'Aventos Hs Servo-Drive Set' -> 'Aventos Hf Servo-Drive Set'
#   'Barrel Height: 2-3/4"' -> 'Barrel Height 2-3/4"'
#   'Base Plate Height 0' -> 'Base Plate Height'
#   'Base Plates' -> 'Base Plate'
#   'Baseplate' -> 'Base Plate'
#   'Blind Corner Application' -> 'Blind Corner Applications'
#   'Blind Corner Hinges' -> 'Blind Corner Hinge'
#   'Blum 970A Blumotion' -> 'Blum 971A Blumotion'
#   'Bp20K1101T' -> 'Bp20K1101'
#   'Bp20K1301T' -> 'Bp20K1301'
#   'Bp20K1501T' -> 'Bp20K1501'
#   'Bp20K4101' -> 'Bp20K4101A'
#   'Bp20S4200' -> 'Bp20S4200A'
#   'Bp701553-Onyx' -> 'Bp701503-Onyx'
#   'Bp704503-Onyx' -> 'Bp701503-Onyx'
#   'Bp70T3504-Onyx' -> 'Bp70T7504-Onyx'
#   'Bp73T550Ab' -> 'Bp73T550A'
#   'Bumper Pads' -> 'Bumper Pad'
#   'Cabinet Door' -> 'Cabinet Doors'
#   'Cabinet Sidewall' -> 'Cabinet Side Wall'
#   'Clip Top 107° Hinges' -> 'Clip Top 110°+ Hinges'
#   'Clip Top 110°+ Hinges' -> 'Clip Top 110° Hinges'
#   'Clip Top 120°' -> 'Clip Top 110°'
#   'Clip Top 120° Hinges' -> 'Clip Top 107° Hinges'
#   'Clip Top 120°+ Hinges' -> 'Clip Top 107° Hinges'
#   'Clip Top 170°' -> 'Clip Top 110°'
#   'Clip Top 170° Hinge' -> 'Clip Top 107° Hinges'
#   'Compact 38C Hinges' -> 'Compact 38N Hinges'
#   'Corner Cabinet' -> 'Corner Cabinets'
#   'Corrosion Resistant' -> 'Corrosion Resistance'
#   'Counter-A-Syst 326' -> 'Counter-A-Syst 325'
#   'Counter-A-Syst 327' -> 'Counter-A-Syst 325'
#   'Counter-A-Syst 328' -> 'Counter-A-Syst 325'
#   'Countersunk Screw M5 X 6Mm' -> 'Countersunk Screw M4 X 8Mm'
#   'Cover Cap' -> 'Cover Caps'
#   'Cover Cap For Flap Hinge' -> 'Cover Caps For Flap Hinges'
#   'Cover Caps For Hinges' -> 'Cover Cap For Hinges'
#   'Crew-On' -> 'Screw-On'
#   'Depth Adjustment +3/- 2Mm' -> 'Depth Adjustment +3/-1Mm'
#   'Depth Adjustment +3/-2Mm' -> 'Depth Adjustment +3/- 2Mm'
#   'Design Solutions' -> 'Design Solution'
#   'Die-Cast' -> 'Diecast'
#   'Door Mounting Plates' -> 'Door Mounting Plate'
#   'Door Thickness Up To 28Mm' -> 'Door Thickness Up To 25Mm'
#   'Door Thickness Up To 3/4"' -> 'Door Thickness Up To 1-3/8"'
#   'Door Thickness Up To 30Mm' -> 'Door Thickness Up To 25Mm'
#   'Door Thickness Up To 7/8"' -> 'Door Thickness Up To 1-3/8"'
#   'Door Thicknesses 14 To 24Mm' -> 'Door Thicknesses 16 To 22Mm'
#   'Door Thicknesses 15 To 21Mm' -> 'Door Thicknesses 14 To 24Mm'
#   'Door Thicknesses 16 To 24 Mm' -> 'Door Thicknesses 14 To 24Mm'
#   'Door Thicknesses Up To 36 Mm' -> 'Door Thicknesses Up To 36Mm'
#   'Dspro110Cafd' -> 'Dspro110Caf'
#   'Dspro114-2Cdsc' -> 'Dspro114-2Cd'
#   'Dspro114-3Cdsc' -> 'Dspro114-3Cd'
#   'Dspro12-3Cdsc' -> 'Dspro12-2Cdsc'
#   'Dspro125Cafd' -> 'Dspro125Caf'
#   'Dsproih76-26D' -> 'Dsproih74-26D'
#   'Euro Screw' -> 'Euro Screws'
#   'Euro Screw 13Mm Pozi' -> 'Euro Screw 11Mm Pozi'
#   'Euro Screws (6.3Mm X 13.5Mm)' -> 'Euro Screws (6.3 X 13.5)'
#   'F017139417228' -> 'F017139416228'
#   'F028138522228' -> 'F028138521228'
#   'F028138525228' -> 'F028138521228'
#   'F028138526228' -> 'F028138521228'
#   'F028138569228' -> 'F028138568228'
#   'F028138572228' -> 'F028138521228'
#   'F028138573228' -> 'F028138570228'
#   'F028138574228' -> 'F028138570228'
#   'F034139387217' -> 'F034139388217'
#   'F034139412228' -> 'Gff034139412228'
#   'F045138281228' -> 'F045138280228'
#   'F045138282228' -> 'F045138280228'
#   'F045138328228' -> 'F045138280228'
#   'F045138463228' -> 'F045138460228'
#   'F045138464228' -> 'F045138460228'
#   'F053139675223' -> 'F053139672223'
#   'F053139676223' -> 'F053139672223'
#   'F053139678223' -> 'F053139672223'
#   'F053139684223' -> 'F053139683223'
#   'F058149675228' -> 'F058149674228'
#   'F059139702228' -> 'F059139701228'
#   'F059139703228' -> 'F059139701228'
#   'F059139711228' -> 'F059139701228'
#   'F059139713228' -> 'F059139701228'
#   'F072135503228' -> 'Gff072135503228'
#   'Face Frame Adapter Plat' -> 'Face Frame Adapter Plates'
#   'Face Frame Adapters' -> 'Face Frame Adapter'
#   'Face Frame Application' -> 'Face Frame Applications'
#   'Face Frame Cabinetry' -> 'Face Frame Cabinets'
#   'Faceframe Application' -> 'Face Frame Application'
#   'Ff072135751517' -> 'Gff072135751517'
#   'Fixing Screw' -> 'Fixing Screws'
#   'Flap Hinge' -> 'Flap Hinges'
#   'For Wood Screw' -> 'For Wood Screws'
#   'Free-Swing' -> 'Free Swing'
#   'Free-Swinging' -> 'Free Swinging'
#   'Free-Swinging Hinges' -> 'Free Swinging Hinges'
#   'Full Overlay Hinge' -> 'Full Overlay Hinges'
#   'Gf146.700.02.0015' -> 'Gf146.700.01.0015'
#   'Gf148.405.11.9615' -> 'Gf148.405.12.9615'
#   'Gf148.700.01.0015' -> 'Gf146.700.01.0015'
#   'Gf314.393.69.0215' -> 'Gf314.393.69.0015'
#   'Gf314.493.70.0015' -> 'Gf314.493.71.0015'
#   'Gf314.493.70.0215' -> 'Gf314.493.70.0015'
#   'Gf314.493.70.0415' -> 'Gf314.493.70.0015'
#   'Gf314.493.70.0815' -> 'Gf314.493.70.0015'
#   'Gf314.493.71.0215' -> 'Gf314.493.71.0015'
#   'Gf318.393.81.0215' -> 'Gf318.393.81.0015'
#   'Gf318.393.81.0415' -> 'Gf318.393.81.0015'
#   'Gf318.493.70.0015' -> 'Gf314.493.70.0015'
#   'Gf318.493.70.0215' -> 'Gf318.493.71.0215'
#   'Gf318.493.71.0015' -> 'Gf314.493.71.0015'
#   'Gf346.290.88.0415' -> 'Gf346.290.88.0015'
#   'Gf346.290.90.0215' -> 'Gf346.290.91.0215'
#   'Gf346.290.91.0015' -> 'Gf346.290.91.0415'
#   'Gf346.290.91.0415' -> 'Gf346.290.91.0215'
#   'Gf346.290.92.0015' -> 'Gf346.290.91.0015'
#   'Gff017139424223' -> 'Gff017139432223'
#   'Gff017139427223' -> 'Gff017139425223'
#   'Gff017139432223' -> 'Gff017139425223'
#   'Gff017139441228' -> 'Gff017139417228'
#   'Gff028138526228' -> 'Gff028138522228'
#   'Gff028138533223' -> 'Gff028138530223'
#   'Gff028138543223' -> 'Gff028138530223'
#   'Gff045138460228' -> 'F045138460228'
#   'Gff045138472223' -> 'Gff045138471223'
#   'Gff045138481223' -> 'Gff045138471223'
#   'Gff046140366213' -> 'Gff046140360213'
#   'Gff051139126507' -> 'Gff051139125507'
#   'Gff053139665607' -> 'Gff053139664607'
#   'Gff053139666607' -> 'Gff053139664607'
#   'Gff053139677223' -> 'Gff053139671223'
#   'Gff058139822228' -> 'Gff058139821228'
#   'Gff058139823228' -> 'Gff058139821228'
#   'Gff058139824228' -> 'Gff058139821228'
#   'Gff058139829228' -> 'Gff058139821228'
#   'Gff146101310201' -> 'Gff146101308201'
#   'Gff151135906201' -> 'Gff151135905201'
#   'Gff151145221513' -> 'Gff151145220513'
#   'Gff151147682201' -> 'Gff151147681201'
#   'Gff152145243201' -> 'Gff152145238201'
#   'Gff152145244201' -> 'Gff152145241201'
#   'Gff152145247201' -> 'Gff152145241201'
#   'Grass Kinvaro Lifter Systems' -> 'Grass Kinvaro Lift Systems'
#   'Grass Tec Self-Close Hinges' -> 'Grass Tec Soft-Close Hinges'
#   'Half-Overlay' -> 'Half Overlay'
#   'Heavy-Duty' -> 'Heavy Duty'
#   'Height Adjustment +/-2Mm' -> 'Height Adjustment ± 2Mm'
#   'Height Adjustment Of +/- 2Mm' -> 'Height Adjustment +/-2Mm'
#   'Height Adjustment Of +/-2Mm' -> 'Height Adjustment +/-2Mm'
#   'Height Adjustment ± 1Mm' -> 'Height Adjustment ±2Mm'
#   'Height Adjustment ±2Mm' -> 'Height Adjustment ± 2Mm'
#   'Hinge Arm Cover Cap' -> 'Hinge Arm Cover Caps'
#   'Hinge Arm Cover Cap, Long' -> 'Hinge Arm Cover Cap Long'
#   'Hinge Arms' -> 'Hinge Arm'
#   'Hinge Systems' -> 'Hinge System'
#   'Hold Down Clamps Sets' -> 'Hold Down Clamp Set'
#   'Ihp8491-26D' -> 'Ihp849-26D'
#   'Inserta Hinges' -> 'Inset Hinges'
#   'Inset Doors' -> 'Inset Door'
#   'Institutional Hinge' -> 'Institutional Hinges'
#   'Ip Top 95° Thick Door' -> 'Clip Top 95° Thick Door'
#   'Kinvaro Lift Systems' -> 'Kinvaro Lifter Systems'
#   'Kinvaro T-57 Lift-Up Fitting' -> 'Kinvaro T-76 Lift-Up Fitting'
#   'Kinvaro T-57 Set' -> 'Kinvaro T-76 Set'
#   'Kinvaro T-65 Set' -> 'Kinvaro T-76 Set'
#   'Kinvaro T-71 Lift-Up Fitting' -> 'Kinvaro T-76 Lift-Up Fitting'
#   'Kinvaro T-71 Set' -> 'Kinvaro T-76 Set'
#   'Lid Supports & Stays' -> 'Lid Supports & Up Stays'
#   'Lift Mechanism' -> 'Lift Mechanisms'
#   'Lift Mechanism Sets' -> 'Lift Mechanism Set'
#   'Lift-A-Syst 522' -> 'Lift-A-Syst 521'
#   'Lift-A-Syst 523' -> 'Lift-A-Syst 521'
#   'Lift-A-Syst 524' -> 'Lift-A-Syst 521'
#   'Lift-A-Syst 525' -> 'Lift-A-Syst 521'
#   'Lift-A-Syst 526' -> 'Lift-A-Syst 521'
#   'Maintenance-Free' -> 'Maintenance Free'
#   'Material Thickness 0.095"' -> 'Material Thickness 0.083"'
#   'Mb 8510 Hinge Arm' -> 'Mb 8310 Hinge Arm'
#   'Mb Series Barrel Hinge' -> 'Mb Series Barrel Hinges'
#   'Medium-Duty' -> 'Medium Duty'
#   'Minimum Gaps' -> 'Minimum Gap'
#   'Mm Dowel For Tec Hinges' -> '8Mm Dowel For Tec Hinges'
#   'Mounting Plate' -> 'Mounting Plates'
#   'Nexis 110°' -> 'Nexis 110'
#   'Nexis 110° Hinges' -> 'Nexis 100° Hinges'
#   'Nexis 125°' -> 'Nexis 125'
#   'Nexis 170 Hinges' -> 'Nexis 170 Hinge'
#   'Nexis 170°' -> 'Nexis 170'
#   'Nexis 170° Hinges' -> 'Nexis 100° Hinges'
#   'Nexis 170° Wide-Angle Hinges' -> 'Nexis 170 Wide Angle Hinge'
#   'Nexis 95/90' -> 'Nexis 95/90°'
#   'Nexis 95°' -> 'Nexis 95'
#   'Nickel Plated' -> 'Nickel-Plated'
#   'Nickel-Plated Steel' -> 'Nickel Plated Steel'
#   'Non Handed' -> 'Non-Handed'
#   'Opening Angle 110°' -> 'Opening Angle 100°'
#   'Opening Angle: Max -5°' -> 'Opening Angle: Max -10°'
#   'Overlay Hinge' -> 'Overlay Hinges'
#   'Overlays Up To 19Mm' -> 'Overlay Up To 19Mm'
#   'Packaged In Full Boxes Of 150' -> 'Packaged In Full Boxes Of 250'
#   'Panel Application' -> 'Panel Applications'
#   'Pie-Cut Corner Applications' -> 'Pie-Cut Corner Application'
#   'Pie-Cut Corner Hinges' -> 'Pie-Cut Corner Hinge'
#   'Pivot Hinges For Inset Doors' -> 'Pivot Hinge For Inset Doors'
#   'Push To Open' -> 'Push-To-Open'
#   'Reduces Opening Angle To 85º' -> 'Reduces Opening Angle To 86°'
#   'Replacement 8Mm Bit' -> 'Replacement 35Mm Bit'
#   'Salice Hinges Series F' -> 'Salice Hinges Series B'
#   'Screw On' -> 'Crew-On'
#   'Screw-O Fixing' -> 'Screw Fixing'
#   'Self Close' -> 'Self-Close'
#   'Self-Close Hinges' -> 'Self-Close Hinge'
#   'Side Adjustment ± 2Mm' -> 'Side Adjustment ±2Mm'
#   'Single Phase - 110V Power' -> 'Single Phase - 220V Power'
#   'Soft Close Damper' -> 'Soft-Close Damper'
#   'Soft-Close Adapters' -> 'Soft-Close Adapter'
#   'Soft-Close Hinge' -> 'Soft-Close Hinges'
#   'Soft-Close Impresso Adapter' -> 'Soft-Close Impresson Adapter'
#   'Spring' -> 'Springs'
#   'Steel, Nickel Plated' -> 'Steel/Nickel Plated'
#   'Steel, Nickel-Plate' -> 'Steel, Nickel Plated'
#   'Steel/Nickel Plated' -> 'Steel, Nickel-Plated'
#   'Straight Base Plates' -> 'Straight Base Plate'
#   'Style #5' -> 'Style #65'
#   'Style #6' -> 'Style #65'
#   'System Screws' -> 'System Screw'
#   'Tec Hinges' -> 'Tec Hinge'
#   'Thick Doors' -> 'Thick Door'
#   'Three Dimensional Adjustment' -> 'Three-Dimensional Adjustment'
#   'Tiomos 110/30E' -> 'Tiomos 110/30A'
#   'Tiomos 110/45A' -> 'Tiomos 110/45E'
#   'Tiomos 110/90' -> 'Tiomos 110/90E'
#   'Tiomos 110/90A' -> 'Tiomos 110/30A'
#   'Tiomos 120/-15A' -> 'Tiomos 120/-45A'
#   'Tiomos 155 Hinges' -> 'Tiomos 155 Hinge'
#   'Tiomos Flap Hinges' -> 'Tiomos Flap Hinge'
#   'Tiomos H Hinges' -> 'Tiomos Hinges'
#   'Tool Free' -> 'Tool-Free'
#   'Ubfrakfexwsn9' -> 'Ubfrakfexdsn9'
#   'Ubsrxa78Acsnxxf' -> 'Ubsrxa78A0Snxxf'
#   'Ubsrxa78Aisnxxf' -> 'Ubsrxa78A0Snxxf'
#   'Ubsrxa78Ansnxxf' -> 'Ubsrxa78A0Snxxf'
#   'Weight Specification' -> 'Height Specification'
#   'Width: Up To 47-1/4" (1200Mm)' -> 'Width Up To 47-1/4" (1200Mm)'
#   'Wing Adapters' -> 'Wing Adapter'
#   'Wing Base Plate Positioning' -> 'Wing Base Plate Position'
#   'Wing Base Plate, 4-Point Fixing' -> 'Wing Base Plate, 4 Point Fixing'
#   'Wing Base Plates' -> 'Wing Base Plate'
#   'Wood Screws' -> 'Wood Screw'
#   'Wood Screws, Nickel-Plated' -> 'Wood Screw, Nickel-Plated'
#   'Wy2245' -> 'Wy2245B'
#   'Ydbp65-Ab' -> 'Ydbp6-Ab'
#   'Ydbp65-Np' -> 'Ydbp6-Np'
#   'Ydcm65-Ab' -> 'Ydcm6-Ab'
#   'Ydcm65-Bp' -> 'Ydcm6-Bp'
#   'Ydcm65-Np' -> 'Ydcm6-Np'
#   'Zinc Die-Cast' -> 'Zinc Die Cast'
#   'Zinc, Nickel Plated' -> 'Zinc, Nickel-Plated'
#   'Zinc-Diecast' -> 'Zinc Die Cast'
#
# Deduplication applied to all extractions

# %%
# === Filter low-value / noise entities ===
STOP_ENTITIES = {
    "N/A", "None", "Unknown", "Other", "Yes", "No", "See", "Page",
    "Table", "Figure", "Note", "Section", "Mm", "Kg", "Lbs", "Item #",
    "Contents", "Index", "Catalog", "Overview",
}

before_entities = sum(len(ex.get("entities", [])) for ex in all_extractions)
before_rels = sum(len(ex.get("relationships", [])) for ex in all_extractions)

for ex in all_extractions:
    ex["entities"] = [
        e for e in ex.get("entities", [])
        if isinstance(e.get("name"), str)
        and len(e["name"].strip()) >= 3
        and e["name"].strip().title() not in STOP_ENTITIES
        and not e["name"].strip().replace(".", "").replace(",", "").replace("/", "").replace("-", "").replace(" ", "").isdigit()
    ]
    ex["relationships"] = [
        r for r in ex.get("relationships", [])
        if isinstance(r.get("source"), str) and len(r["source"].strip()) >= 3
        and isinstance(r.get("target"), str) and len(r["target"].strip()) >= 3
    ]

after_entities = sum(len(ex.get("entities", [])) for ex in all_extractions)
after_rels = sum(len(ex.get("relationships", [])) for ex in all_extractions)

print(f"Filtered entities: {before_entities} -> {after_entities} (removed {before_entities - after_entities})")
print(f"Filtered relationships: {before_rels} -> {after_rels} (removed {before_rels - after_rels})")
# Out:
# Filtered entities: 7583 -> 7438 (removed 145)
# Filtered relationships: 5750 -> 5690 (removed 60)

# %% [markdown]
# ## 5. Build the Knowledge Graph
#
# We use NetworkX to construct a graph from the extracted entities and relationships. Entity names are normalized to merge duplicates.

# %%
import networkx as nx


def normalize_name(name: str) -> str:
    """Normalize entity names for consistent matching."""
    if not isinstance(name, str):
        name = str(name) if name is not None else ""
    return name.strip().title()


# Build the graph
G = nx.Graph()

for extraction in all_extractions:
    source_file = extraction["source"]
    page = extraction["page"]
    chunk_id = extraction["chunk_id"]

    # Add entity nodes
    for entity in extraction["entities"]:
        name = normalize_name(entity.get("name", ""))
        etype = entity.get("type", "unknown")
        if not name or len(name) < 2:
            continue

        if G.has_node(name):
            G.nodes[name]["mentions"] = G.nodes[name].get("mentions", 1) + 1
            G.nodes[name]["sources"].add(source_file)
            G.nodes[name]["chunk_ids"].add(chunk_id)
            # Type majority voting
            G.nodes[name]["type_votes"][etype] = G.nodes[name]["type_votes"].get(etype, 0) + 1
            G.nodes[name]["type"] = max(G.nodes[name]["type_votes"], key=G.nodes[name]["type_votes"].get)
        else:
            G.add_node(
                name,
                type=etype,
                mentions=1,
                sources={source_file},
                chunk_ids={chunk_id},
                type_votes={etype: 1},
            )

    # Add relationship edges
    for rel in extraction["relationships"]:
        src = normalize_name(rel.get("source", ""))
        tgt = normalize_name(rel.get("target", ""))
        relation = rel.get("relation", "has_feature")
        if not src or not tgt or len(src) < 2 or len(tgt) < 2:
            continue

        for node_name in [src, tgt]:
            if not G.has_node(node_name):
                # Infer type: if it appears as an entity elsewhere, use that type
                inferred_type = "product"  # default for relationship endpoints
                G.add_node(node_name, type=inferred_type, mentions=1, sources={source_file},
                           chunk_ids={chunk_id}, type_votes={inferred_type: 1})

        if G.has_edge(src, tgt):
            G.edges[src, tgt]["weight"] = G.edges[src, tgt].get("weight", 1) + 1
            G.edges[src, tgt]["relations"].add(relation)
        else:
            G.add_edge(src, tgt, weight=1, relations={relation})

print(f"Knowledge Graph:")
print(f"  Nodes (entities): {G.number_of_nodes()}")
print(f"  Edges (relationships): {G.number_of_edges()}")
print(f"  Connected components: {nx.number_connected_components(G)}")
print(f"  Average degree: {sum(d for _, d in G.degree()) / max(G.number_of_nodes(), 1):.1f}")
print(f"  Density: {nx.density(G):.4f}")

# Entity type distribution
from collections import Counter
type_dist = Counter(data.get("type", "?") for _, data in G.nodes(data=True))
print(f"\nEntity types: {dict(type_dist.most_common())}")

# Relationship type distribution
rel_dist = Counter()
for _, _, data in G.edges(data=True):
    for r in data.get("relations", set()):
        rel_dist[r] += 1
print(f"Relationship types: {dict(rel_dist.most_common())}")

# Top entities by mention count
top_entities = sorted(G.nodes(data=True), key=lambda x: x[1].get("mentions", 0), reverse=True)[:15]
print(f"\nTop 15 entities:")
for name, data in top_entities:
    print(f"  {name} ({data.get('type', '?')}): {data.get('mentions', 0)} mentions, {len(data.get('sources', set()))} sources")
# Out:
# Knowledge Graph:
#   Nodes (entities): 3218
#   Edges (relationships): 4546
#   Connected components: 441
#   Average degree: 2.8
#   Density: 0.0009
#
# Entity types: {'product': 1362, 'specification': 883, 'feature': 757, 'category': 113, 'material': 78, 'certification': 16, 'manufacturer': 9}
# Relationship types: {'has_feature': 1591, 'has_specification': 1587, 'part_of': 685, 'compatible_with': 324, 'variant_of': 260, 'manufactured_by': 176}
#
# Top 15 entities:
#   Grass (manufacturer): 119 mentions, 4 sources
#   Nickel-Plated (material): 87 mentions, 4 sources
#   Base Plate (product): 74 mentions, 3 sources
#   Concealed Hinges (category): 74 mentions, 2 sources
#   Steel (material): 70 mentions, 4 sources
#   Drilling Distance (specification): 66 mentions, 2 sources
#   Tiomos (product): 66 mentions, 4 sources
#   Screw-On (feature): 64 mentions, 4 sources
#   Self-Close (feature): 58 mentions, 4 sources
#   Cover Caps (product): 57 mentions, 4 sources
#   Soft-Close (feature): 54 mentions, 4 sources
#   Door Thickness (specification): 54 mentions, 2 sources
#   Base Plate Height (specification): 52 mentions, 2 sources
#   3-Dimensional Adjustment (feature): 51 mentions, 4 sources
#   Dowelled (feature): 44 mentions, 4 sources

# %% [markdown]
# ## 6. Community Detection
#
# We detect communities (clusters of densely connected entities) using the Louvain algorithm. Each community represents a thematic grouping — e.g., a product line with its features and specs.

# %%
# Detect communities using Louvain method
communities = nx.community.louvain_communities(G, seed=42)

# Assign community IDs to nodes
for community_id, community_nodes in enumerate(communities):
    for node in community_nodes:
        G.nodes[node]["community"] = community_id

print(f"Detected {len(communities)} communities\n")

# Show the largest communities
sorted_communities = sorted(enumerate(communities), key=lambda x: len(x[1]), reverse=True)

for community_id, members in sorted_communities[:8]:
    # Get top members by mentions
    top_members = sorted(members, key=lambda n: G.nodes[n].get("mentions", 0), reverse=True)[:6]
    member_str = ", ".join(top_members)
    if len(members) > 6:
        member_str += f", ... (+{len(members)-6} more)"
    print(f"Community {community_id} ({len(members)} entities): {member_str}")
# Out:
# Detected 480 communities
#
# Community 0 (312 entities): Grass, Base Plate, Tiomos, Drilling Distance, Screw-On, Door Thickness, ... (+306 more)
# Community 95 (210 entities): Concealed Hinges, Self-Close, 3-Dimensional Adjustment, 45Mm, 110° Opening Angle, 42/45Mm, ... (+204 more)
# Community 5 (205 entities): Nickel-Plated, Steel, Cover Caps, Wood Screw, Steel, Nickel-Plated, Hinge Cup Cover Cap, ... (+199 more)
# Community 346 (180 entities): Blum, Blumotion, Lift Mechanisms, Face Frame Applications, Lift Mechanism Set, Aventos Lift Systems, ... (+174 more)
# Community 183 (149 entities): Soft-Close, 110°, Soft-Close Adapter, Soft-Close Damper, 125°, Dowel, ... (+143 more)
# Community 386 (125 entities): White, 50,000 Cycles, Gray, Heavy Duty, Non-Handed, Lid Supports & Up Stays, ... (+119 more)
# Community 400 (120 entities): Semi-Concealed Hinges, Institutional Hinges, Dull Chrome, Counter-A-Syst 325, 45Mm Pattern, Satin Chrome, ... (+114 more)
# Community 343 (116 entities): Lift Systems, Aluminum, Wood, Face Frame Adapter, Arm Assembly Mounting Plates, Bp20S4200A, ... (+110 more)

# %% [markdown]
# ## 7. Visualize the Knowledge Graph
#
# Interactive visualization using pyvis. Nodes are colored by community and sized by mention count.

# %%
from pyvis.network import Network

# Build a subgraph of the most-connected entities for a readable visualization
# (full graph can be overwhelming)
MIN_MENTIONS = 3  # Only include entities mentioned at least this many times
notable_nodes = [n for n, d in G.nodes(data=True) if d.get("mentions", 0) >= MIN_MENTIONS]
subgraph = G.subgraph(notable_nodes)

print(f"Visualizing subgraph: {subgraph.number_of_nodes()} nodes, {subgraph.number_of_edges()} edges")
print(f"(Entities with >= {MIN_MENTIONS} mentions)\n")

# Color palette for communities
COLORS = [
    "#e6194b", "#3cb44b", "#4363d8", "#f58231", "#911eb4",
    "#42d4f4", "#f032e6", "#bfef45", "#fabed4", "#469990",
    "#dcbeff", "#9A6324", "#800000", "#aaffc3", "#808000",
]

net = Network(height="700px", width="100%", notebook=True, cdn_resources="in_line")
net.barnes_hut(gravity=-5000, spring_length=200)

for node in subgraph.nodes():
    data = G.nodes[node]
    community_id = data.get("community", 0)
    color = COLORS[community_id % len(COLORS)]
    size = min(10 + data.get("mentions", 1) * 3, 50)
    title = f"{node}\nType: {data.get('type', '?')}\nMentions: {data.get('mentions', 0)}\nCommunity: {community_id}"
    net.add_node(node, label=node, color=color, size=size, title=title)

for src, tgt, data in subgraph.edges(data=True):
    relations = ", ".join(data.get("relations", set()))
    net.add_edge(src, tgt, title=relations, width=min(data.get("weight", 1), 5))

# Write HTML with explicit UTF-8 encoding (fixes Windows cp1252 error)
html_path = Path("../knowledge_graph.html")
net.generate_html()
with open(html_path, "w", encoding="utf-8") as f:
    f.write(net.html)

print(f"Graph saved to {html_path.resolve()}")
print("Open it in a browser for the interactive visualization.")
# Out:
# Visualizing subgraph: 522 nodes, 919 edges
# (Entities with >= 3 mentions)
#
# Graph saved to C:\Users\steph\source\repos\micro-x-rag\knowledge_graph.html
# Open it in a browser for the interactive visualization.

# %% [markdown]
# ## 8. Community Summaries
#
# Generate natural language summaries for each community. These summaries enable answering broad, thematic questions that standard RAG struggles with.

# %%
SUMMARY_PROMPT = """You are summarizing a cluster of related entities from hardware product catalogs.

Given the following entities and their relationships, write a concise summary (2-4 sentences)
describing what this group represents, the key products/features, and how they relate.

ENTITIES:
{entities}

RELATIONSHIPS:
{relationships}

SUMMARY:"""


def summarize_community(community_nodes: set, graph: nx.Graph) -> str:
    """Generate a natural language summary for a community."""
    # Collect entity info
    entity_strs = []
    for node in sorted(community_nodes, key=lambda n: graph.nodes[n].get("mentions", 0), reverse=True)[:20]:
        data = graph.nodes[node]
        entity_strs.append(f"- {node} (type: {data.get('type', '?')}, mentions: {data.get('mentions', 0)})")

    # Collect relationships within the community
    rel_strs = []
    for src, tgt, data in graph.edges(data=True):
        if src in community_nodes and tgt in community_nodes:
            relations = ", ".join(data.get("relations", set()))
            rel_strs.append(f"- {src} --[{relations}]--> {tgt}")

    if not entity_strs:
        return "Empty community."

    prompt = SUMMARY_PROMPT.format(
        entities="\n".join(entity_strs[:20]),
        relationships="\n".join(rel_strs[:30]) or "No relationships found.",
    )

    return llm_chat(prompt, provider=SUMMARY_PROVIDER, model=SUMMARY_MODEL, temperature=0.3, max_tokens=512)


# Summarize the top communities (by size)
community_summaries = {}
top_n_communities = min(10, len(sorted_communities))

print(f"Generating summaries for top {top_n_communities} communities ({SUMMARY_PROVIDER} / {SUMMARY_MODEL})...\n")
for community_id, members in sorted_communities[:top_n_communities]:
    if len(members) < 3:  # Skip tiny communities
        continue
    summary = summarize_community(members, G)
    community_summaries[community_id] = {
        "summary": summary,
        "size": len(members),
        "top_entities": sorted(members, key=lambda n: G.nodes[n].get("mentions", 0), reverse=True)[:5],
    }
    print(f"Community {community_id} ({len(members)} entities):")
    print(f"  Key entities: {', '.join(community_summaries[community_id]['top_entities'])}")
    print(f"  Summary: {summary}\n")
# Out:
# Generating summaries for top 10 communities (anthropic / claude-sonnet-4-20250514)...
#
# Community 0 (312 entities):
#   Key entities: Grass, Base Plate, Tiomos, Drilling Distance, Screw-On
#   Summary: This cluster represents Grass's comprehensive cabinet hinge systems, primarily featuring their Nexis and Tiomos product lines. The Nexis hinge series offers advanced functionality with multiple mounting options (screw-on and dowelled), various overlay configurations (full, half, and inset), and flexible specifications including 45mm boring patterns and opening angles from 95° to 170°. Key features include integrated soft-close technology with tool-free options, precise adjustment capabilities (depth, height, and side adjustments), and compatibility with both face frame and frameless applications. The system is supported by various base plate configurations and specifications for door thickness, drilling distance, and reveal measurements, making it a versatile solution for cabinet hardware applications.
#
# Community 95 (210 entities):
#   Key entities: Concealed Hinges, Self-Close, 3-Dimensional Adjustment, 45Mm, 110° Opening Angle
#   Summary: This cluster represents **concealed cabinet hinges** and their associated specifications and features commonly found in furniture hardware catalogs. The key products include full overlay, half overlay, and specialty hinges (like the Tiomos series) that feature standard dimensions of 42-45mm cups with opening angles typically ranging from 110° to 120°. These hinges are characterized by advanced functionality including self-closing mechanisms, 3-dimensional adjustment capabilities for precise door alignment, and specialized features like depth adjustment with worm gear and various mounting options (screw-on fixing, press-in dowels). The relationships show that self-closing functionality is a dominant feature across most hinge models, indicating this is a premium product category focused on convenience and precision adjustment for cabinet door applications.
#
# Community 5 (205 entities):
#   Key entities: Nickel-Plated, Steel, Cover Caps, Wood Screw, Steel, Nickel-Plated
#   Summary: This cluster represents a comprehensive cabinet hinge system, primarily featuring Nexis hinges and their associated components. The system includes hinge arms made from nickel-plated steel or diecast materials, various mounting plates with 2-point fixing mechanisms, and protective cover caps. Key features include snap-on attachment with audible clicks, soft-close technology, and precise adjustment capabilities (±2mm for side and depth), with components connected through Euro screws and wood screws for secure cabinet installation.
#
# Community 346 (180 entities):
#   Key entities: Blum, Blumotion, Lift Mechanisms, Face Frame Applications, Lift Mechanism Set
#   Summary: This cluster represents Blum's comprehensive cabinet hardware system, with a primary focus on their Aventos lift mechanisms and hinge solutions. The core products include Aventos lift systems (featuring variants like Hf, Hl, and Hk-S) that provide smooth vertical door operation, complemented by Clip Top hinges with specifications like 107° and 100° opening angles for face frame and panel applications. Key technological features across the product line include Blumotion silent closing, Tip-On touch-to-open functionality, tool-free assembly, and specialized components like magnetic tips and mounting hardware. Blum positions itself as a premium manufacturer offering integrated solutions that combine lift mechanisms, hinges, and advanced motion technologies for modern cabinet applications.
#
# Community 183 (149 entities):
#   Key entities: Soft-Close, 110°, Soft-Close Adapter, Soft-Close Damper, 125°
#   Summary: This cluster represents cabinet hinge systems with integrated soft-close functionality, primarily featuring various angle specifications and damping mechanisms. The core products include soft-close adapters, dampers, and complete hinge systems (like Tiomos M9 and Grass Nexis series) that offer opening angles ranging from 110° to 170° for different cabinet door applications. Key features include adjustable damping force, tool-free installation, overload safety mechanisms, and compatibility with various door thicknesses (12mm-28mm) and flat panel doors. These components work together to provide smooth, controlled cabinet door closing across different hinge angles and installation requirements.
#
# Community 386 (125 entities):
#   Key entities: White, 50,000 Cycles, Gray, Heavy Duty, Non-Handed
#   Summary: This cluster represents cabinet hardware components, primarily focusing on hinges, lid supports, and door movement mechanisms. The key products include piano hinges, lid supports with soft-close and soft-open functionality, and tip-on wing adapter plates, available in multiple color options (white, gray, antique English) and duty ratings (light, medium, heavy duty). These components feature non-handed designs for universal installation and offer varying cycle ratings (30,000-50,000 cycles) to accommodate different usage requirements. The products work together to provide smooth, controlled movement for cabinet doors and lids, with specialized mounting specifications like 37mm setback positioning and adjustable features such as speed control screws and springs.
#
# Community 400 (120 entities):
#   Key entities: Semi-Concealed Hinges, Institutional Hinges, Dull Chrome, Counter-A-Syst 325, 45Mm Pattern
#   Summary: This cluster represents **Semi-Concealed Hinges** for cabinet and institutional applications, with Institutional Hinges and MB Series Barrel Hinges being the primary product categories. These hinges are designed for heavy-duty use, featuring wide opening angles (180°-270°), multiple finish options (Dull Chrome, Satin Chrome, Satin Black), and ANSI/BHMA Grade I certification for durability. Key specifications include compatibility with various door thicknesses (up to 1-3/8"), standardized hole patterns (32mm, 45mm), and specialized features like tool-free snap-on mounting and frameless cabinet construction. The products are engineered for institutional settings requiring reliable, adjustable hinges that can handle frequent use while maintaining easy installation and removal capabilities.
#
# Community 343 (116 entities):
#   Key entities: Lift Systems, Aluminum, Wood, Face Frame Adapter, Arm Assembly Mounting Plates
#   Summary: This cluster represents **Lift Systems** hardware for cabinet doors, primarily featuring lift-up and bi-fold mechanisms that work with various door materials. The key products include **Kinvaro Lifter Systems**, **Face Frame Adapters**, and specialized hardware sets designed for either wood/wide aluminum doors or narrow aluminum doors, with the **Kinvaro T-76 Lift-Up Fitting** being a notable component. These systems are engineered to be compatible with multiple materials including aluminum, wood, MDF, chipboard, mineral composite, and HPL, using material-specific fasteners and mounting hardware. The products feature advanced functionality such as adjustable spring force, integrated closing dampers, and variable opening angles to provide smooth, controlled door operation across different cabinet applications.
#
# Community 403 (100 entities):
#   Key entities: Würth Baer Supply, 11Mm Cup Depth, Lifetime Warranty, Lift-A-Syst 521, Flap Hinges
#   Summary: This cluster represents a comprehensive range of cabinet hinges and mounting hardware primarily manufactured by Würth Baer Supply. The product line includes various hinge types such as flap hinges, Euro hinges, and specialty hinges (including the Lift-A-Syst 521 and Series 200), featuring advanced functionality like integrated soft-close motion, self-closing mechanisms, and self-lubricating properties. Key specifications include standardized dimensions such as 11mm cup depth, up to 25mm door thickness compatibility, and 105-degree opening angles, with many products offering corrosion resistance and lifetime warranties. The products are designed for professional cabinet installation with precise adjustment capabilities and accommodate various overlay requirements up to 21mm.
#
# Community 14 (95 entities):
#   Key entities: 95° Opening Angle, Tipmatic Pin System, Tiomos Flap Hinge, 95°, Min Reveal
#   Summary: This cluster represents cabinet hinge systems from hardware catalogs, primarily featuring the Nexis and Tiomos product lines. The key products include various hinge models (Nexis 95, 110, 125, and Tiomos variants) designed for different opening angles (95° and 110°) and door configurations, with the Tipmatic Pin System providing enhanced functionality. Most hinges in this group are soft-close compatible or feature soft-close add-ons, and they share common specifications like minimum reveal requirements (1.5mm) and adjustment mechanisms via eccentric cams. These products cater to different cabinet applications including standard profile doors, corner cabinets, and flap hinges, offering various overlay options and load-bearing capacities for comprehensive cabinet hardware solutions.

# %% [markdown]
# ## 9. Build ChromaDB Vector Store
#
# We store both the original chunks AND the community summaries in ChromaDB. This gives us vector search over raw text plus graph-derived knowledge.

# %%
import httpx
import chromadb
from chromadb.api.types import EmbeddingFunction, Documents, Embeddings


class OllamaEmbeddingFunction(EmbeddingFunction):
    def __init__(self, model: str = EMBED_MODEL, base_url: str = OLLAMA_BASE_URL):
        self.model = model
        self.base_url = base_url

    def __call__(self, input: Documents) -> Embeddings:
        embeddings = []
        batch_size = 32
        for i in range(0, len(input), batch_size):
            batch = input[i : i + batch_size]
            response = httpx.post(
                f"{self.base_url}/api/embed",
                json={"model": self.model, "input": batch},
                timeout=120.0,
            )
            response.raise_for_status()
            embeddings.extend(response.json()["embeddings"])
        return embeddings


embed_fn = OllamaEmbeddingFunction()
chroma_client = chromadb.PersistentClient(path=str(CHROMA_PERSIST_DIR.resolve()))

# --- Chunks collection ---
try:
    chroma_client.delete_collection("graph_rag_chunks")
except ValueError:
    pass

chunks_collection = chroma_client.create_collection(
    name="graph_rag_chunks",
    embedding_function=embed_fn,
    metadata={"hnsw:space": "cosine"},
)

print(f"Adding {len(all_chunks)} chunks...")
BATCH_SIZE = 50
for i in range(0, len(all_chunks), BATCH_SIZE):
    batch = all_chunks[i : i + BATCH_SIZE]
    chunks_collection.add(
        ids=[c["id"] for c in batch],
        documents=[c["text"] for c in batch],
        metadatas=[c["metadata"] for c in batch],
    )
    print(f"  {min(i + BATCH_SIZE, len(all_chunks))}/{len(all_chunks)}", end="\r")

# --- Community summaries collection ---
try:
    chroma_client.delete_collection("graph_rag_communities")
except ValueError:
    pass

community_collection = chroma_client.create_collection(
    name="graph_rag_communities",
    embedding_function=embed_fn,
    metadata={"hnsw:space": "cosine"},
)

if community_summaries:
    community_collection.add(
        ids=[f"community_{cid}" for cid in community_summaries],
        documents=[cs["summary"] for cs in community_summaries.values()],
        metadatas=[{"community_id": cid, "size": cs["size"], "top_entities": ", ".join(cs["top_entities"])} for cid, cs in community_summaries.items()],
    )

print(f"\nChunks collection: {chunks_collection.count()} documents")
print(f"Community collection: {community_collection.count()} summaries")
# Out:
# Adding 676 chunks...
#   676/676
# Chunks collection: 676 documents
# Community collection: 10 summaries

# %% [markdown]
# ## 10. GraphRAG Retrieval
#
# The GraphRAG retrieval strategy combines three signals:
#
# 1. **Vector search** — find relevant text chunks (same as standard RAG)
# 2. **Graph traversal** — find entities mentioned in top chunks, then pull in their neighbors and connected information
# 3. **Community summaries** — find relevant high-level summaries for thematic context

# %%
def graph_retrieve(query: str, n_chunks: int = 5, n_communities: int = 2, hop_depth: int = 1) -> dict:
    """GraphRAG retrieval: vector search + graph traversal + community summaries."""

    # 1. Vector search on chunks
    chunk_results = chunks_collection.query(query_texts=[query], n_results=n_chunks)
    retrieved_chunks = []
    for i in range(len(chunk_results["ids"][0])):
        retrieved_chunks.append({
            "id": chunk_results["ids"][0][i],
            "text": chunk_results["documents"][0][i],
            "metadata": chunk_results["metadatas"][0][i],
            "distance": chunk_results["distances"][0][i],
        })

    # 2. Graph traversal: find entities in retrieved chunks, get their neighbors
    retrieved_chunk_ids = set(chunk_results["ids"][0])
    graph_entities = set()
    graph_context_parts = []

    for node, data in G.nodes(data=True):
        node_chunks = data.get("chunk_ids", set())
        if node_chunks & retrieved_chunk_ids:
            graph_entities.add(node)

            # Get neighbors up to hop_depth
            neighbors = set()
            current_level = {node}
            for _ in range(hop_depth):
                next_level = set()
                for n in current_level:
                    next_level.update(G.neighbors(n))
                neighbors.update(next_level)
                current_level = next_level

            graph_entities.update(neighbors)

    # Build graph context: entity descriptions and their relationships
    for entity in sorted(graph_entities, key=lambda n: G.nodes[n].get("mentions", 0), reverse=True)[:15]:
        node_data = G.nodes[entity]
        # Get edges for this entity
        edges = []
        for _, neighbor, edge_data in G.edges(entity, data=True):
            if neighbor in graph_entities:
                rels = ", ".join(edge_data.get("relations", set()))
                edges.append(f"{entity} --[{rels}]--> {neighbor}")

        if edges:
            graph_context_parts.append(
                f"{entity} ({node_data.get('type', '?')}, {node_data.get('mentions', 0)} mentions):\n"
                + "\n".join(f"  {e}" for e in edges[:5])
            )

    # 3. Community summaries
    community_results = community_collection.query(query_texts=[query], n_results=n_communities)
    retrieved_communities = []
    for i in range(len(community_results["ids"][0])):
        retrieved_communities.append({
            "id": community_results["ids"][0][i],
            "summary": community_results["documents"][0][i],
            "metadata": community_results["metadatas"][0][i],
            "distance": community_results["distances"][0][i],
        })

    return {
        "chunks": retrieved_chunks,
        "graph_context": "\n\n".join(graph_context_parts),
        "graph_entities_found": len(graph_entities),
        "communities": retrieved_communities,
    }


# Test it
result = graph_retrieve("What soft-close hinge options are available?")
print(f"Chunks retrieved: {len(result['chunks'])}")
print(f"Graph entities found: {result['graph_entities_found']}")
print(f"Communities matched: {len(result['communities'])}")
print(f"\nGraph context preview:\n{result['graph_context'][:500]}")
# Out:
# Chunks retrieved: 5
# Graph entities found: 0
# Communities matched: 2
#
# Graph context preview:

# %% [markdown]
# ## 11. GraphRAG Generation
#
# Build the prompt with all three context sources and generate answers with both Ollama and Claude.

# %%
def build_graph_rag_prompt(query: str, retrieval: dict) -> str:
    """Build a prompt combining chunk context, graph context, and community summaries."""

    # Chunk context (same as standard RAG)
    chunk_parts = []
    for i, chunk in enumerate(retrieval["chunks"], 1):
        src = chunk["metadata"]["source"]
        page = chunk["metadata"]["page"]
        chunk_parts.append(f"[Source {i}: {src}, Page {page}]\n{chunk['text']}")
    chunk_context = "\n\n---\n\n".join(chunk_parts)

    # Graph context
    graph_context = retrieval["graph_context"] or "No graph relationships found."

    # Community summaries
    community_context = "\n".join(
        f"- {c['summary']}" for c in retrieval["communities"]
    ) or "No community summaries available."

    return f"""You are a knowledgeable hardware product specialist. Answer the user's question
using ALL the provided context. You have three sources of information:

1. CATALOG TEXT — direct excerpts from product catalogs
2. KNOWLEDGE GRAPH — extracted entity relationships showing how products, features, and specs connect
3. THEMATIC SUMMARIES — high-level summaries of product clusters

Use all three to give a comprehensive answer. Cite source catalogs and page numbers when possible.
If the context doesn't contain enough information, say so clearly.

=== CATALOG TEXT ===
{chunk_context}

=== KNOWLEDGE GRAPH (entity relationships) ===
{graph_context}

=== THEMATIC SUMMARIES ===
{community_context}

USER QUESTION: {query}

ANSWER:"""


def graph_rag_query(query: str) -> str:
    """Full GraphRAG pipeline using ANSWER_PROVIDER / ANSWER_MODEL."""
    retrieval = graph_retrieve(query)
    prompt = build_graph_rag_prompt(query, retrieval)
    return llm_chat(prompt, provider=ANSWER_PROVIDER, model=ANSWER_MODEL, temperature=0.3, max_tokens=1024)


# Test
query = "What soft-close hinge options are available and how do they compare?"
print(f"Query: {query}")
print(f"Answer: {ANSWER_PROVIDER} / {ANSWER_MODEL}\n")
print("=" * 60)
print(graph_rag_query(query))
# Out:
# Query: What soft-close hinge options are available and how do they compare?
# Answer: anthropic / claude-sonnet-4-20250514
#
# ============================================================
# Based on the catalog information provided, there are several soft-close hinge options available, primarily featuring the **Grass Tiomos system** offered through Würth Baer Supply. Here's a comprehensive comparison:
#
# ## Available Soft-Close Hinge Options
#
# ### Tiomos Soft-Close Hinges
# The catalogs show **two main angle configurations**:
#
# **110° Tiomos Soft-Closing Hinges** (wurth-baer-section-b-concealed-hinges.pdf, Page 45):
# - Available in 42mm dowelled and 45mm screw-on configurations
# - Full overlay hinges with up to 7/8" (22mm) overlay capability
#
# **120° Tiomos Soft-Closing Hinges** (wurth-baer-section-b-concealed-hinges.pdf, Page 46):
# - Same configuration options as 110° version
# - Also available in 42mm dowelled and 45mm screw-on
#
# ### Additional Soft-Close Options
# The catalog also lists other soft-close hinges with various specifications (wurth-baer-section-b-concealed-hinges.pdf, Page 47):
# - Multiple boring patterns (42mm, 45mm, and 42/45mm)
# - Various fixing methods: Dowelled, Screw-on, and Impresso (Tool Free)
# - Different overlay configurations including Full Overlay and standard Overlay options
#
# ## Key Comparison Features
#
# ### Adjustment Capabilities
# All Tiomos soft-close hinges share these features:
# - **3 adjustable closing performance settings** - allowing customization for different door weights and preferences
# - **Tool-free adjustment** - can be adjusted even after doors are installed
# - **3-dimensional adjustment capability** including depth adjustment (+3/-2mm) and height adjustment (±2mm to ±2.5mm) (grass-tiomos-catalog.pdf, Page 5)
#
# ### Performance Characteristics
# - **Uniform closing action** regardless of door size, weight, or materials
# - **Fully integrated and concealed mechanism** within the hinge arm for clean aesthetics
# - **Continuous soft-close action** throughout the entire closing duration (grass-tiomos-catalog.pdf, Page 3)
#
# ### Packaging
# - 110° and 120° Tiomos hinges: **Packaged in boxes of 150**
# - Other soft-close options: **Packaged in boxes of 50**
# - All available in any quantity
#
# ## Summary
# The Tiomos system appears to be the premium option, offering superior engineering with fully integrated soft-close technology, multiple adjustment options, and consistent performance across different door specifications. The main choice factors are the opening angle needed (110° vs 120°), boring pattern requirements, and preferred mounting method (dowelled vs screw-on vs tool-free).
#
# The thematic summaries indicate this is part of a broader ecosystem that includes opening angles up to 170°, though specific details for those aren't provided in the catalog excerpts shown.

# %% [markdown]
# ## 12. Compare: Standard RAG vs GraphRAG
#
# We test both approaches on queries that highlight GraphRAG's strengths: broad, thematic, and cross-document questions.

# %%
def standard_rag_query(query: str, n_results: int = 5) -> str:
    """Standard RAG (vector-only) for comparison. Uses ANSWER_PROVIDER / ANSWER_MODEL."""
    results = chunks_collection.query(query_texts=[query], n_results=n_results)
    context_parts = []
    for i in range(len(results["ids"][0])):
        src = results["metadatas"][0][i]["source"]
        page = results["metadatas"][0][i]["page"]
        context_parts.append(f"[Source {i+1}: {src}, Page {page}]\n{results['documents'][0][i]}")

    context = "\n\n---\n\n".join(context_parts)
    prompt = f"""You are a knowledgeable hardware product specialist. Answer the user's question
based ONLY on the provided catalog context. If the context doesn't contain enough
information to fully answer the question, say so clearly.

When referencing specific products or specifications, cite the source catalog and page number.

CONTEXT FROM PRODUCT CATALOGS:
{context}

USER QUESTION: {query}

ANSWER:"""

    return llm_chat(prompt, provider=ANSWER_PROVIDER, model=ANSWER_MODEL, temperature=0.3, max_tokens=1024)


# Comparison queries — designed to test different strengths
comparison_queries = [
    # Broad/thematic — GraphRAG advantage
    "What are the main product categories across all catalogs and how do they relate?",
    # Cross-document — GraphRAG advantage
    "Compare the hinge systems from Grass and Wurth Baer.",
    # Multi-hop — GraphRAG advantage
    "What mounting plates are compatible with soft-close hinges?",
    # Specific fact — Standard RAG is fine
    "What is the maximum opening angle for Tiomos hinges?",
]

print(f"Answer provider: {ANSWER_PROVIDER} / {ANSWER_MODEL}\n")

for query in comparison_queries:
    print("\n" + "#" * 70)
    print(f"QUERY: {query}")
    print("#" * 70)

    print(f"\n--- Standard RAG ---")
    print(standard_rag_query(query))

    print(f"\n--- GraphRAG ---")
    print(graph_rag_query(query))
    print()
# Out:
# Answer provider: anthropic / claude-sonnet-4-20250514
#
#
# ######################################################################
# QUERY: What are the main product categories across all catalogs and how do they relate?
# ######################################################################
#
# --- Standard RAG ---
# Based on the provided catalog context, I can identify several main product categories, though the context is limited and doesn't provide a complete overview of all catalogs.
#
# **Main Product Categories Identified:**
#
# From **Wurth_Baer_Section_C.pdf, Page 1**:
# - Pin/Knife Hinges (pages C-51 - C-52)
# - SOSS Invisible Hinges (pages C-44 - C-45)
# - Institutional Hinges (pages C-39 - C-42)
# - Lid Supports & Stays (pages C-33 - C-37)
#
# From **wurth-baer-section-b-concealed-hinges.pdf**:
# - Concealed Hinges and related hardware
# - Hinge accessories and installation tools (drill bits, centering bits)
# - Hinge Soft-Close Adapters
#
# **How They Relate:**
# These categories appear to be part of a comprehensive cabinet and door hardware system:
#
# 1. **Hinges** form the core category with multiple specialized types:
#    - Concealed hinges for modern cabinet applications
#    - Pin/knife hinges for traditional applications
#    - Invisible hinges for seamless appearance
#    - Institutional hinges for heavy-duty commercial use
#
# 2. **Support Hardware** complements the hinge systems:
#    - Lid supports and stays for overhead applications
#    - Soft-close adapters for enhanced functionality
#
# 3. **Installation Tools** support the hardware installation:
#    - Specialized drill bits and centering tools for proper hinge installation
#
# However, I should note that the provided context doesn't contain enough information to give you a complete picture of all product categories across all catalogs, as I only have limited excerpts from what appears to be a larger catalog system. For a comprehensive overview of all product categories and their relationships, you would need access to the complete catalog sections and any master product index.
#
# --- GraphRAG ---
# Based on the catalog text and thematic summaries, I can identify several main product categories across the Würth Baer catalogs and their relationships:
#
# ## Main Product Categories
#
# ### 1. **Concealed Hinges** (Section B)
# - **Nexis and Tiomos hinge lines** with various opening angles (95°, 110°, 125°)
# - **Different door configurations** and overlay options
# - **Soft-close compatible models** and soft-close add-ons
# - **Specialized applications** including corner cabinets and flap hinges
#
# ### 2. **Visible Hinges** (Section C)
# According to Wurth_Baer_Section_C.pdf (Page 1), this includes:
# - **Pin/Knife Hinges** (pages C-51 - C-52)
# - **SOSS Invisible Hinges** (pages C-44 - C-45)
# - **Institutional Hinges** (pages C-39 - C-42)
#
# ### 3. **Lid Supports & Stays** (Section C, pages C-33 - C-37)
# - **Multiple duty ratings**: Light, medium (173-216 lbs/sq in torque), and heavy duty (216-260 lbs/sq in torque)
# - **Directional options**: Left and right configurations
# - **Soft-close and soft-open functionality** with cycle ratings of 30,000-50,000 cycles
#
# ### 4. **Hinge Accessories and Hardware**
# - **Soft-close adapters**: Including Salice Type "L" Smove adjustable soft-close systems
# - **Installation hardware**: Inset recesses ranging from 6mm to 29mm with corresponding fractional measurements
# - **Drilling accessories**: Speed steel bits and centering tools for installation
#
# ## How These Categories Relate
#
# **Functional Integration**: The categories work together as a comprehensive cabinet hardware system. Concealed hinges provide the primary door movement mechanism, while soft-close adapters enhance functionality across both hinge types.
#
# **Application Overlap**: Both concealed and visible hinges can utilize the same soft-close technology and installation accessories, creating a unified system approach.
#
# **Duty Rating Consistency**: The lid supports' duty rating system (light/medium/heavy) appears to complement the load-bearing specifications found in the hinge systems.
#
# **Installation Compatibility**: The drilling accessories and installation hardware serve multiple product categories, indicating these systems are designed to work with common installation methods and tools.
#
# *Note: Some items may not be available in all markets according to the catalog disclaimer (Wurth_Baer_Section_C.pdf, Page 1).*
#
#
# ######################################################################
# QUERY: Compare the hinge systems from Grass and Wurth Baer.
# ######################################################################
#
# --- Standard RAG ---
# I cannot provide a comparison between Grass and Wurth Baer hinge systems because the provided catalog context only contains information about Grass hinge systems (specifically the Tiomos and Nexis series). There is no information about Wurth Baer products in the available documentation.
#
# From the catalogs provided, I can tell you about the Grass hinge systems:
#
# **Grass Tiomos System** [Source: grass-tiomos-catalog.pdf, Pages 3-4]:
# - Described as an "evolutionary hinge system"
# - Offers standard Self-close and Soft-close options
# - Available in 45mm or 42mm boring patterns for dowelled hinges, 45mm for screw-on hinges
# - Tiomos Impresso (tool-free version) available in combined 42/45mm pattern
# - Covers applications from standard to wide angle doors, frameless to face frame
#
# **Grass Nexis System** [Source: grass-nexis-catalog.pdf, Pages 1-3]:
# - Features snap-on technology for quick mounting
# - Nexis Impresso offers tool-free installation
# - Available in 42mm, 45mm, and 48mm boring patterns
# - Opening angles from 95° to 170°
# - Suitable for face frame or frameless applications
#
# To provide a proper comparison with Wurth Baer products, I would need catalog information or specifications for their hinge systems.
#
# --- GraphRAG ---
# Based on the provided context, I can only provide information about Grass hinge systems, as there is no information about Wurth Baer hinge systems in the catalog materials provided.
#
# ## Grass Hinge Systems
#
# Grass offers two main hinge system lines based on the catalog information:
#
# ### Tiomos System
# **Source: grass-tiomos-catalog.pdf, Pages 3-4**
#
# - **Positioning**: Described as "an evolutionary hinge system" that "outperforms any other hinge in the industry"
# - **Applications**: Covers virtually every application from standard doors to wide angle doors, diagonal corner hinges to pie-cut corner hinges
# - **Compatibility**: Both frameless and face frame applications
# - **Boring Patterns**:
#   - 45mm or 42mm for dowelled hinges
#   - 45mm for screw-on hinges
#   - Tiomos Impresso offers combined 42/45mm pattern
# - **Closing Actions**: Standard Self-close and Soft-close with three-tier adjustable mechanism
# - **Design**: Features "timeless design" with integrated and concealed soft-close mechanism in the hinge arm
#
# ### Nexis System
# **Source: grass-nexis-catalog.pdf, Pages 1-3**
#
# - **Positioning**: Described as "the classic choice among hinge systems" with "proven technology"
# - **Key Technology**: Snap-on technology for quick, efficient, secure mounting
# - **Nexis Impresso**: Tool-free installation version designed for flat-packed cabinetry
# - **Applications**: Face frame and frameless applications, including blind corner and pie-cut corner applications
# - **Opening Angles**: Range from 95° to 170°
# - **Boring Patterns**: Available in 42mm, 45mm, and 48mm patterns
# - **Installation**: 3-point connection system prevents twisting, offers cam adjustment on base plates
#
# ## Missing Information
#
# **I cannot provide a comparison with Wurth Baer hinge systems** because the provided context contains no information about Wurth Baer products, catalogs, or specifications. To make a meaningful comparison, I would need catalog text, technical specifications, or other documentation about Wurth Baer's hinge systems.
#
# If you have Wurth Baer catalog information or specifications available, please provide that context so I can offer a comprehensive comparison between the two manufacturers' hinge systems.
#
#
# ######################################################################
# QUERY: What mounting plates are compatible with soft-close hinges?
# ######################################################################
#
# --- Standard RAG ---
# Based on the provided catalog context, I cannot find specific information about which mounting plates are compatible with soft-close hinges.
#
# The catalog sections provided focus on the soft-close adapters themselves and mention that:
#
# - Soft-close Nexis adapters are compatible with Nexis 95°, 100°, 110°, and 125° hinges (Source 1: grass-nexis-catalog.pdf, Page 37)
# - Soft-close Nexis Impresso adapters are compatible with Nexis Impresso 95°, 100°, 110°, and 125° hinges (Source 2: grass-nexis-catalog.pdf, Page 36)
# - The hinges use "Snap-on base plates" for attachment (Source 3: grass-nexis-catalog.pdf, Page 2)
#
# However, the catalog excerpts don't contain detailed specifications about mounting plate compatibility or part numbers for base plates that work with soft-close systems. To get complete information about mounting plate compatibility with soft-close hinges, you would need to reference additional pages of the catalog or contact Grass directly, as suggested in their installation guidelines.
#
# --- GraphRAG ---
# Based on the provided catalog information, I can only provide limited details about mounting plates compatible with soft-close hinges, as the context focuses primarily on the soft-close adapters themselves rather than comprehensive mounting plate compatibility.
#
# ## Available Information from Grass Nexis Catalog:
#
# **Nexis Snap-on Base Plates:**
# From the Grass Nexis catalog (Page 2), the system uses "Nexis base plates" that work with snap-on technology. The catalog states that "Nexis Snap-on hinges attach to Nexis base plates with an audible click" and notes that "The versatile Nexis hinge system offers snap-on installation technology for a variety of cabinetry applications with a Soft-close or Self-close closing action."
#
# **Soft-close Compatibility Requirements:**
# The catalog emphasizes checking "for notches to verify Soft-close compatibility" (Page 37), suggesting that mounting plates need specific design features to work with soft-close systems.
#
# **Boring Pattern Options:**
# The Nexis system offers multiple boring patterns:
# - 42mm, 45mm, 48mm boring patterns for screw-on and dowelled versions
# - 42/45mm and 45/48mm boring patterns for Nexis Impresso (tool-free installation)
#
# ## Limited Context Acknowledgment:
#
# The provided catalog excerpts focus heavily on the soft-close adapters and hinges themselves but don't include detailed specifications or part numbers for the compatible mounting plates. For comprehensive information about specific mounting plate models, dimensions, and complete compatibility charts, you would need to contact Grass directly or reference additional catalog sections not included in this context.
#
# **Source:** grass-nexis-catalog.pdf, Pages 2, 36-37
#
# For complete mounting plate specifications and compatibility information, I recommend contacting the Grass factory directly, as suggested in their installation guidelines.
#
#
# ######################################################################
# QUERY: What is the maximum opening angle for Tiomos hinges?
# ######################################################################
#
# --- Standard RAG ---
# Based on the provided catalog context, I cannot find any information about Tiomos hinges or their maximum opening angles. The catalogs provided contain information about:
#
# - Wurth-Baer CLIP top hinges with various opening angles (110°, 125°, 155°, 170°)
# - Grass Nexis hinges with opening angles from 95° to 170°
# - AIR hinges with 105° opening angle
#
# However, none of these sources mention Tiomos hinges specifically. To answer your question about the maximum opening angle for Tiomos hinges, I would need catalog information that specifically covers the Tiomos product line.
#
# --- GraphRAG ---
# Based on the provided context, I cannot find specific information about the maximum opening angle for Tiomos hinges.
#
# While the catalog text mentions Tiomos hinges briefly in the thematic summary as part of a specialty hinge series with "opening angles typically ranging from 110° to 120°," this appears to be a general reference rather than a definitive specification for the maximum opening angle of Tiomos hinges specifically.
#
# The catalog excerpts provided focus primarily on:
# - Würth Baer CLIP top hinges with various opening angles (108°, 110°, 155°, 170°) and their angle restriction clips
# - Grass Nexis hinges with opening angles from 95° to 170°
# - AIR hinges with 105° opening angle
#
# To provide you with the accurate maximum opening angle specification for Tiomos hinges, I would need access to the specific Tiomos product catalog pages or technical specifications that aren't included in the current context.

# %% [markdown]
# ## 13. Interactive GraphRAG Query

# %%
# Change this query
my_query = "What are all the different hinge types and their key specifications?"

print(f"Query: {my_query}")
print(f"Answer provider: {ANSWER_PROVIDER}\n")

# Retrieve with full GraphRAG
retrieval = graph_retrieve(my_query)

print(f"Retrieved {len(retrieval['chunks'])} chunks")
print(f"Found {retrieval['graph_entities_found']} related entities in knowledge graph")
print(f"Matched {len(retrieval['communities'])} community summaries")

print("\nSources:")
for c in retrieval["chunks"]:
    print(f"  - {c['metadata']['source']}, Page {c['metadata']['page']} (distance: {c['distance']:.4f})")
print()

print(graph_rag_query(my_query))
# Out:
# Query: What are all the different hinge types and their key specifications?
# Answer provider: anthropic
#
# Retrieved 5 chunks
# Found 0 related entities in knowledge graph
# Matched 2 community summaries
#
# Sources:
#   - grass-nexis-catalog.pdf, Page 2 (distance: 0.2054)
#   - grass-tiomos-catalog.pdf, Page 4 (distance: 0.2169)
#   - grass-nexis-catalog.pdf, Page 3 (distance: 0.2282)
#   - grass-nexis-catalog.pdf, Page 3 (distance: 0.2309)
#   - grass-tiomos-catalog.pdf, Page 3 (distance: 0.2343)
#
# Based on the provided catalog information, there are two main hinge systems with several variations:
#
# ## Nexis Hinge System
#
# **Key Specifications:**
# - **Opening angles:** 95° to 170° (grass-nexis-catalog.pdf, Page 2)
# - **Boring patterns:** 42mm, 45mm, and 48mm (grass-nexis-catalog.pdf, Page 2)
# - **Mounting options:** Screw-on and dowelled versions (grass-nexis-catalog.pdf, Page 2)
# - **Applications:** Standard doors, specialty doors, frame and frameless applications (grass-nexis-catalog.pdf, Page 2)
#
# **Nexis Variants:**
# 1. **Standard Nexis:** Traditional snap-on hinges with audible click attachment to base plates (grass-nexis-catalog.pdf, Page 2)
# 2. **Nexis Impresso:** Tool-free installation version available in 42/45mm and 45/48mm boring patterns (grass-nexis-catalog.pdf, Page 2)
#
# **Special Features:**
# - Snap-on technology for quick, secure mounting (grass-nexis-catalog.pdf, Page 3)
# - 3-point connection system preventing twisting (grass-nexis-catalog.pdf, Page 3)
# - Cam adjustment on base plates (grass-nexis-catalog.pdf, Page 3)
# - Suitable for blind corner and pie-cut corner applications (grass-nexis-catalog.pdf, Page 3)
#
# ## Tiomos Hinge System
#
# **Key Specifications:**
# - **Boring patterns:** 42mm and 45mm for dowelled hinges, 45mm for screw-on hinges (grass-tiomos-catalog.pdf, Page 4)
# - **Applications:** Standard doors, wide angle doors, diagonal corner hinges, pie-cut corner hinges, frameless and face frame applications (grass-tiomos-catalog.pdf, Page 4)
#
# **Tiomos Variants:**
# 1. **Standard Tiomos:** Available with self-close action (grass-tiomos-catalog.pdf, Page 3)
# 2. **Tiomos with Soft-close:** Features three-tier adjustable mechanism integrated in hinge arm (grass-tiomos-catalog.pdf, Page 3)
# 3. **Tiomos Impresso:** Tool-free version available in combined 42/45mm pattern (grass-tiomos-catalog.pdf, Page 4)
#
# **Special Features:**
# - Fully integrated and concealed soft-close mechanism (grass-tiomos-catalog.pdf, Page 3)
# - Smooth action throughout the entire closing duration (grass-tiomos-catalog.pdf, Page 3)
#
# The thematic summaries indicate additional specifications including minimum reveal requirements (1.5mm), various overlay options (full, half, and inset), and compatibility with different door thicknesses, though specific measurements for these aren't detailed in the provided catalog excerpts.

# %% [markdown]
# ## 14. Explore the Knowledge Graph
#
# Utilities for querying the graph directly.

# %%
def explore_entity(name: str, depth: int = 1):
    """Show an entity's connections in the knowledge graph."""
    name = normalize_name(name)
    if name not in G:
        # Fuzzy match
        matches = [n for n in G.nodes() if name.lower() in n.lower()]
        if matches:
            print(f"'{name}' not found exactly. Did you mean: {', '.join(matches[:5])}?")
            name = matches[0]
            print(f"Showing results for '{name}':\n")
        else:
            print(f"Entity '{name}' not found in graph.")
            return

    data = G.nodes[name]
    print(f"Entity: {name}")
    print(f"  Type: {data.get('type', '?')}")
    print(f"  Mentions: {data.get('mentions', 0)}")
    print(f"  Sources: {', '.join(data.get('sources', set()))}")
    print(f"  Community: {data.get('community', '?')}")
    print(f"  Connections:")

    for neighbor in sorted(G.neighbors(name), key=lambda n: G.nodes[n].get("mentions", 0), reverse=True):
        edge_data = G.edges[name, neighbor]
        rels = ", ".join(edge_data.get("relations", set()))
        n_data = G.nodes[neighbor]
        print(f"    --[{rels}]--> {neighbor} ({n_data.get('type', '?')}, {n_data.get('mentions', 0)} mentions)")


# Try it
explore_entity("Tiomos")
# Out:
# Entity: Tiomos
#   Type: product
#   Mentions: 66
#   Sources: wurth-baer-section-b-concealed-hinges.pdf, Wurth_Baer_Section_C.pdf, grass-nexis-catalog.pdf, grass-tiomos-catalog.pdf
#   Community: 0
#   Connections:
#     --[manufactured_by]--> Grass (manufacturer, 119 mentions)
#     --[has_feature, compatible_with, part_of]--> Base Plate (product, 74 mentions)
#     --[part_of]--> Concealed Hinges (category, 74 mentions)
#     --[has_specification]--> Drilling Distance (specification, 66 mentions)
#     --[has_feature]--> Screw-On (feature, 64 mentions)
#     --[has_feature]--> Self-Close (feature, 58 mentions)
#     --[has_feature]--> Soft-Close (feature, 54 mentions)
#     --[has_specification]--> Door Thickness (specification, 54 mentions)
#     --[has_specification]--> Base Plate Height (specification, 52 mentions)
#     --[has_feature]--> 3-Dimensional Adjustment (feature, 51 mentions)
#     --[has_feature]--> Dowelled (feature, 44 mentions)
#     --[has_specification]--> Reveal (specification, 43 mentions)
#     --[has_specification]--> 45Mm Boring Pattern (specification, 38 mentions)
#     --[has_specification, has_feature]--> Half Overlay (feature, 35 mentions)
#     --[has_specification]--> Door Overlay (specification, 34 mentions)
#     --[part_of]--> Hinges (product, 33 mentions)
#     --[has_specification, has_feature]--> Overlay (feature, 32 mentions)
#     --[has_specification, has_feature]--> Full Overlay (feature, 28 mentions)
#     --[has_specification]--> Minimum Gap (specification, 27 mentions)
#     --[has_feature, part_of]--> Hinge Arm (product, 26 mentions)
#     --[part_of]--> Hinge Cup Cover Cap (product, 26 mentions)
#     --[has_specification, has_feature]--> Inset (feature, 25 mentions)
#     --[has_feature, variant_of]--> Impresso (feature, 22 mentions)
#     --[part_of]--> Hinge Clip Protector (product, 19 mentions)
#     --[has_specification]--> Center Cup (specification, 18 mentions)
#     --[compatible_with]--> 85° Angle Reduction Clip (product, 18 mentions)
#     --[part_of]--> Hinge Cup (product, 17 mentions)
#     --[part_of]--> Cover Cap With Clip Protector (product, 17 mentions)
#     --[has_specification]--> Gap (specification, 16 mentions)
#     --[has_specification]--> Cup Dimensions (specification, 16 mentions)
#     --[has_feature]--> Depth Adjustment (feature, 14 mentions)
#     --[has_feature]--> Height Adjustment (feature, 13 mentions)
#     --[has_specification]--> Bph (specification, 13 mentions)
#     --[has_feature]--> Side Adjustment (feature, 12 mentions)
#     --[has_specification]--> Minimum Reveal (specification, 12 mentions)
#     --[has_specification]--> Base Plate Setback (specification, 12 mentions)
#     --[compatible_with]--> Face Frame Cabinets (category, 12 mentions)
#     --[has_specification]--> 110° (specification, 12 mentions)
#     --[compatible_with]--> Frameless Cabinets (category, 11 mentions)
#     --[has_feature]--> Depth Adjustment With Worm Gear (feature, 11 mentions)
#     --[has_feature]--> Soft-Close Damper (product, 10 mentions)
#     --[has_specification, compatible_with]--> Bph 02 (product, 10 mentions)
#     --[compatible_with]--> Door Stop (product, 9 mentions)
#     --[part_of]--> Wing Base Plate (product, 9 mentions)
#     --[variant_of]--> Full Overlay Hinges (product, 9 mentions)
#     --[has_feature]--> Worm Screw (feature, 8 mentions)
#     --[has_specification]--> 24Mm Door Thickness (specification, 8 mentions)
#     --[part_of]--> Straight Base Plate (product, 8 mentions)
#     --[part_of]--> Hinge System (category, 7 mentions)
#     --[has_feature]--> Face Frame Applications (feature, 7 mentions)
#     --[variant_of]--> Overlay Hinges (product, 7 mentions)
#     --[variant_of]--> Tiomos Hinges (product, 7 mentions)
#     --[compatible_with]--> Pie-Cut Corner Hinge (product, 6 mentions)
#     --[has_specification]--> Cup Center (specification, 6 mentions)
#     --[has_feature]--> Zero Protrusion (feature, 6 mentions)
#     --[has_feature]--> Three-Dimensional Adjustment (feature, 6 mentions)
#     --[manufactured_by]--> Tiomos 110/45E (product, 6 mentions)
#     --[has_feature]--> Uniform Closing Action (feature, 5 mentions)
#     --[has_specification]--> Door Protrusion (specification, 5 mentions)
#     --[part_of]--> Hinge Arm Cover Caps (product, 5 mentions)
#     --[part_of]--> Tiomos Hinge System (product, 4 mentions)
#     --[has_feature]--> Tool-Free Adjustment (feature, 4 mentions)
#     --[has_specification]--> Edge Radius (specification, 4 mentions)
#     --[compatible_with]--> Tipmatic (product, 4 mentions)
#     --[compatible_with]--> Angle Reduction Clip (product, 4 mentions)
#     --[part_of]--> Accessories And Assembly Aids (category, 4 mentions)
#     --[part_of]--> +5° Wedge For Screw Fixing (product, 4 mentions)
#     --[part_of]--> Angle Reduction Clip To 120° (product, 4 mentions)
#     --[compatible_with]--> Standard Doors (product, 3 mentions)
#     --[variant_of]--> Tiomos Impresso (product, 3 mentions)
#     --[variant_of]--> Tiomos 155 (product, 3 mentions)
#     --[has_specification]--> Overlays Up To 24Mm (specification, 3 mentions)
#     --[has_specification]--> Door Thicknesses Up To 36Mm (specification, 3 mentions)
#     --[variant_of]--> Tiomos 95 (product, 3 mentions)
#     --[has_specification]--> Door Thickness Up To 25Mm (specification, 3 mentions)
#     --[has_specification]--> Wing Base Plate Position (specification, 3 mentions)
#     --[part_of]--> Bph 00 (product, 3 mentions)
#     --[compatible_with]--> Countersunk Screw M4 X 8Mm (product, 3 mentions)
#     --[part_of]--> Angle Reduction Clip To 85° (product, 3 mentions)
#     --[compatible_with]--> 3Mm Universal Spacer (product, 2 mentions)
#     --[compatible_with]--> Wide Angle Doors (product, 2 mentions)
#     --[has_feature]--> Frameless Applications (feature, 2 mentions)
#     --[compatible_with]--> Cabinet Doors (product, 2 mentions)
#     --[has_feature]--> Adjustment Lever (feature, 2 mentions)
#     --[part_of]--> Corner (category, 2 mentions)
#     --[has_feature]--> 3 Soft-Close Settings (feature, 2 mentions)
#     --[has_feature]--> Static Load - Vertical (feature, 2 mentions)
#     --[has_feature]--> Static Load - Horizontal (feature, 2 mentions)
#     --[has_feature]--> Endurance Test (feature, 2 mentions)
#     --[has_feature]--> Functional Test (feature, 2 mentions)
#     --[has_feature]--> Overload Testing (feature, 2 mentions)
#     --[has_feature]--> Salt Spray And Humidity Test (feature, 2 mentions)
#     --[has_specification]--> Opening Angle: Max -10° (specification, 2 mentions)
#     --[has_specification]--> 10.8Mm Cup Depth (specification, 2 mentions)
#     --[compatible_with]--> Bph 21 (product, 2 mentions)
#     --[has_specification]--> Corner Angle (specification, 2 mentions)
#     --[has_feature]--> Hinge Attachment (feature, 2 mentions)
#     --[has_feature]--> Soft-Close Technology (feature, 2 mentions)
#     --[part_of]--> Tiomos Wing Base Plates (product, 2 mentions)
#     --[part_of]--> Hinge Arm Cover Cap Long (product, 2 mentions)
#     --[part_of]--> Free Swinging Hinges (category, 2 mentions)
#     --[compatible_with]--> Insertion Die For Tiomos 110°/120° Hinges (product, 2 mentions)
#     --[compatible_with]--> Universal Die For Tiomos 110°/120°/160° Hinges (product, 2 mentions)
#     --[has_feature]--> Smooth Action (feature, 1 mentions)
#     --[has_feature]--> Superb Engineering And Design (feature, 1 mentions)
#     --[has_feature]--> Doors Pull Open With Ease (feature, 1 mentions)
#     --[has_feature]--> Minimal Gaps (feature, 1 mentions)
#     --[compatible_with]--> Diagonal Corner Hinges (product, 1 mentions)
#     --[has_feature]--> Elongated Holes (feature, 1 mentions)
#     --[has_feature]--> Kinematics (feature, 1 mentions)
#     --[has_feature]--> Adjustment (feature, 1 mentions)
#     --[has_specification]--> Angle (specification, 1 mentions)
#     --[has_feature]--> 3-Tier Soft-Close Mechanism (feature, 1 mentions)
#     --[has_feature]--> Continuous Smooth Closing Action (feature, 1 mentions)
#     --[has_feature]--> Wide Selection Of Hinges (feature, 1 mentions)
#     --[has_specification]--> Ansi/Bhma A156.9 Standard (certification, 1 mentions)
#     --[has_specification]--> Additional Load: 44 Lb (20 Kg) (specification, 1 mentions)
#     --[has_specification]--> Additional Load: 66 Lb (30 Kg) (specification, 1 mentions)
#     --[has_specification]--> Force: 40 N (specification, 1 mentions)
#     --[has_specification]--> Force: 80 N (specification, 1 mentions)
#     --[has_specification]--> Weight Approximately 11.5 Lb (5.2 Kg) (specification, 1 mentions)
#     --[has_specification]--> Open And Close Movements: 100,000 (specification, 1 mentions)
#     --[has_feature]--> Convenient Depth Adjustment (feature, 1 mentions)
#     --[has_feature]--> Minimal Reveal (feature, 1 mentions)
#     --[has_specification]--> 23.4Mm Overlay Capacity (specification, 1 mentions)
#     --[has_specification]--> Reveal Dimensions (specification, 1 mentions)
#     --[part_of]--> Bph 12 (product, 1 mentions)
#     --[has_feature]--> Cup (feature, 1 mentions)
#     --[has_specification]--> Minimum Gap And Reveal (specification, 1 mentions)
#     --[compatible_with]--> Countersunk Screw M4 X 8Mm With Sleeve M4 X 5.5Mm (product, 1 mentions)
#     --[part_of]--> Standard Hinges (product, 1 mentions)
#     --[part_of]--> Tiomos Spacer Ring (product, 1 mentions)
#     --[part_of]--> Tiomos Marking Aids (product, 1 mentions)
#     --[part_of]--> Dowel, Tiomos (product, 1 mentions)
#     --[has_feature]--> Smooth Closing Action (feature, 1 mentions)
#     --[variant_of]--> Grass Tiomos Euro Hinges (product, 1 mentions)
#     --[variant_of]--> Grass Tiomos Specialty Euro Hinges (product, 1 mentions)
#     --[variant_of]--> Grass Tiomos Baseplates & Accessories (product, 1 mentions)
#     --[variant_of]--> 160° Tiomos Soft-Closing Hinges (product, 1 mentions)
#     --[variant_of]--> Self-Close Euro Hinges (product, 1 mentions)
#     --[manufactured_by]--> Tiomos M0 125° Hinge For Thin Doors (product, 1 mentions)
#     --[variant_of]--> Tiomos Pcc Pie-Cut Corner Cabinet Hinge (product, 1 mentions)
#     --[manufactured_by]--> Tiomos Thick Baseplates (product, 1 mentions)
#     --[manufactured_by]--> Inline Baseplates (product, 1 mentions)
#     --[compatible_with]--> Grass Tipmatic (product, 1 mentions)
#     --[compatible_with]--> Kinvaro D-S Flap Stay (product, 1 mentions)
#     --[part_of]--> 1.5Mm Spacers For Tiomos Flap Hinges (product, 1 mentions)

# %%
# Find shortest path between two entities
def find_path(entity_a: str, entity_b: str):
    """Find the shortest path between two entities in the knowledge graph."""
    a = normalize_name(entity_a)
    b = normalize_name(entity_b)

    # Fuzzy match
    for name in [a, b]:
        if name not in G:
            matches = [n for n in G.nodes() if name.lower() in n.lower()]
            if matches:
                if name == a:
                    a = matches[0]
                else:
                    b = matches[0]

    try:
        path = nx.shortest_path(G, a, b)
        print(f"Path from '{a}' to '{b}' ({len(path)-1} hops):\n")
        for i in range(len(path) - 1):
            edge = G.edges[path[i], path[i+1]]
            rels = ", ".join(edge.get("relations", set()))
            print(f"  {path[i]} --[{rels}]--> {path[i+1]}")
    except (nx.NetworkXNoPath, nx.NodeNotFound) as e:
        print(f"No path found: {e}")


find_path("Tiomos", "Soft Close")
# Out:
# Path from 'Tiomos' to 'Blumotion Soft Close' (3 hops):
#
#   Tiomos --[has_feature]--> Three-Dimensional Adjustment
#   Three-Dimensional Adjustment --[has_feature]--> 107° Clip Top Hinges
#   107° Clip Top Hinges --[compatible_with]--> Blumotion Soft Close

# %%
# Graph statistics
print("Knowledge Graph Statistics")
print("=" * 40)
print(f"Nodes: {G.number_of_nodes()}")
print(f"Edges: {G.number_of_edges()}")
print(f"Connected components: {nx.number_connected_components(G)}")
print(f"Communities: {len(communities)}")
if G.number_of_nodes() > 0:
    print(f"Average degree: {sum(dict(G.degree()).values()) / G.number_of_nodes():.1f}")
    print(f"Density: {nx.density(G):.4f}")

# Entity type distribution
type_counts = {}
for _, data in G.nodes(data=True):
    t = data.get("type", "unknown")
    type_counts[t] = type_counts.get(t, 0) + 1

print(f"\nEntity types:")
for t, count in sorted(type_counts.items(), key=lambda x: x[1], reverse=True):
    print(f"  {t}: {count}")

# Relationship type distribution
rel_counts = {}
for _, _, data in G.edges(data=True):
    for r in data.get("relations", set()):
        rel_counts[r] = rel_counts.get(r, 0) + 1

print(f"\nRelationship types:")
for r, count in sorted(rel_counts.items(), key=lambda x: x[1], reverse=True):
    print(f"  {r}: {count}")
# Out:
# Knowledge Graph Statistics
# ========================================
# Nodes: 3218
# Edges: 4546
# Connected components: 441
# Communities: 480
# Average degree: 2.8
# Density: 0.0009
#
# Entity types:
#   product: 1362
#   specification: 883
#   feature: 757
#   category: 113
#   material: 78
#   certification: 16
#   manufacturer: 9
#
# Relationship types:
#   has_feature: 1591
#   has_specification: 1587
#   part_of: 685
#   compatible_with: 324
#   variant_of: 260
#   manufactured_by: 176
